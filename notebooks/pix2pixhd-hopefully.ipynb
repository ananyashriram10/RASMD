# %%
# 1. Clone the repo
# !git clone https://github.com/NVIDIA/pix2pixHD
# !cd pix2pixHD

# 2. Install dependencies  
# !pip install torch torchvision
# !pip install dominate

# 3. Create directory structure
# !mkdir -p datasets/rasmd/train_A    # RGB images
# !mkdir -p datasets/rasmd/train_B    # SWIR images  
# !mkdir -p datasets/rasmd/test_A     # RGB test
# !mkdir -p datasets/rasmd/test_B     # SWIR test
# Out:
# Cloning into 'pix2pixHD'...
# remote: Enumerating objects: 343, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 343 (delta 0), reused 0 (delta 0), pack-reused 340 (from 1)
# Receiving objects: 100% (343/343), 55.68 MiB | 49.80 MiB/s, done.
# Resolving deltas: 100% (156/156), done.
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.21.0+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.5.1)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchvision) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchvision) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->torchvision) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->torchvision) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->torchvision) (2024.2.0)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 78.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 62.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 39.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.9 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.1 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 31.1 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.5 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.3 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 85.8 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127
# Collecting dominate
#   Downloading dominate-2.9.1-py2.py3-none-any.whl.metadata (13 kB)
# Downloading dominate-2.9.1-py2.py3-none-any.whl (29 kB)
# Installing collected packages: dominate
# Successfully installed dominate-2.9.1

# %%
import os, json, torch
from torch.utils.data import Dataset
from PIL import Image
from torchvision import transforms
import numpy as np 
class RASMDatasetRGBSWIR(Dataset):
    def __init__(self, data_root, ann_rgb_path, ann_swir_path,
                 transform_rgb=None, transform_swir=None, size=(512, 512)):
        self.rgb_dir  = os.path.join(data_root, "RGB")
        self.swir_dir = os.path.join(data_root, "SWIR")
        self.size = size

        with open(ann_rgb_path, "r") as f:
            ann_rgb = json.load(f)
        with open(ann_swir_path, "r") as f:
            ann_swir = json.load(f)

        # map category_id -> contiguous index
        seen_ids = sorted({a["category_id"] for a in ann_rgb["annotations"]})
        self.cat_id_to_idx = {cid: i for i, cid in enumerate(seen_ids)}
        self.num_classes = len(seen_ids)
        self.idx_to_cat_id = {i: cid for cid, i in self.cat_id_to_idx.items()}

        id2rgb  = {img["id"]: img["file_name"] for img in ann_rgb["images"]}
        id2swir = {img["id"]: img["file_name"] for img in ann_swir["images"]}

        self.image_id_to_anns = {}
        for a in ann_rgb["annotations"]:
            self.image_id_to_anns.setdefault(a["image_id"], []).append(a)

        rgb_files  = set(os.listdir(self.rgb_dir))
        swir_files = set(os.listdir(self.swir_dir))

        self.samples = []
        for img_id in set(id2rgb.keys()).intersection(id2swir.keys()):
            r = id2rgb[img_id]; s = id2swir[img_id]
            if r in rgb_files and s in swir_files:
                self.samples.append((img_id, r, s))

        self.transform_rgb  = transform_rgb  or transforms.Compose([
            transforms.Resize(size, antialias=True),
            transforms.ToTensor(),
        ])
        self.transform_swir = transform_swir or transforms.Compose([
            transforms.Resize(size, antialias=True),
            transforms.ToTensor(),
        ])

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        img_id, rgb_fn, swir_fn = self.samples[idx]
        rgb = Image.open(os.path.join(self.rgb_dir, rgb_fn)).convert("RGB")
        swir = Image.open(os.path.join(self.swir_dir, swir_fn)).convert("L")

        # Get original size (width, height) tuple
        original_size = rgb.size  # Returns (width, height)

        rgb = self.transform_rgb(rgb)
        swir = self.transform_swir(swir)

        boxes, labels = [], []
        for a in self.image_id_to_anns.get(img_id, []):
            x, y, w, h = a["bbox"]
            boxes.append([x, y, x+w, y+h])
            labels.append(self.cat_id_to_idx[a["category_id"]])

        boxes = torch.tensor(boxes, dtype=torch.float32) if boxes else torch.zeros((0,4), dtype=torch.float32)
        labels = torch.tensor(labels, dtype=torch.int64) if labels else torch.zeros((0,), dtype=torch.int64)

        # ✅ FIXED: Access individual width/height components
        scale_x = self.size[0] / original_size[0]  # 512 / original_width
        scale_y = self.size[1] / original_size[1]  # 512 / original_height
    
        if boxes.numel() > 0:
            boxes[:, [0, 2]] *= scale_x  # Scale x coordinates
            boxes[:, [1, 3]] *= scale_y  # Scale y coordinates

        target = {"boxes": boxes, "labels": labels, "image_id": torch.tensor([img_id], dtype=torch.int64)}
        return {"rgb": rgb, "swir": swir}, target


import torch
from torch.utils.data import DataLoader, Subset

def collate_fn(batch):
    samples_list, targets_list = zip(*batch)          
    rgb  = torch.stack([s["rgb"]  for s in samples_list], dim=0)  
    swir = torch.stack([s["swir"] for s in samples_list], dim=0)  
    samples = {"rgb": rgb, "swir": swir}
    return samples, list(targets_list)

data_root = "/kaggle/input/rasmd-objectdetection/RASMD_detection/RASMD_detection/train"    
ann_rgb   = "/kaggle/input/rasmd-objectdetection/RASMD_detection_annotation/train_rgb_align.json"
ann_swir  = "/kaggle/input/rasmd-objectdetection/RASMD_detection_annotation/train_swir_align.json"

full_ds = RASMDatasetRGBSWIR(
    data_root=data_root,
    ann_rgb_path=ann_rgb,
    ann_swir_path=ann_swir,
    size=(512, 512),
)

NUM_CLASSES = full_ds.num_classes 

g = torch.Generator().manual_seed(42)
perm = torch.randperm(len(full_ds), generator=g)
n_val = max(1, int(0.2 * len(full_ds)))
val_idx  = perm[:n_val]
train_idx = perm[n_val:]

train_ds = Subset(full_ds, train_idx)
val_ds   = Subset(full_ds, val_idx)

BATCH_SIZE = 8
NUM_WORKERS = 4

train_loader = DataLoader(
    train_ds, batch_size=BATCH_SIZE, shuffle=True,
    num_workers=NUM_WORKERS, pin_memory=True, collate_fn=collate_fn,
)

val_loader = DataLoader(
    val_ds, batch_size=BATCH_SIZE, shuffle=False,
    num_workers=NUM_WORKERS, pin_memory=True, collate_fn=collate_fn,
)

print(f"✅ Dataset loaded: {len(full_ds)} total samples")
print(f"✅ Training samples: {len(train_ds)}")  
print(f"✅ Validation samples: {len(val_ds)}")
# Out:
# ✅ Dataset loaded: 1432 total samples
# ✅ Training samples: 1146
# ✅ Validation samples: 286

# %%
def convert_rasmd_to_pix2pixhd_format():
    """Fixed conversion - ensures SWIR is single channel"""
    
    os.makedirs("datasets/rasmd/train_A", exist_ok=True)
    os.makedirs("datasets/rasmd/train_B", exist_ok=True) 
    os.makedirs("datasets/rasmd/test_A", exist_ok=True)
    os.makedirs("datasets/rasmd/test_B", exist_ok=True)
    
    print("Converting training data...")
    for i, (samples, targets) in enumerate(train_loader):
        for j in range(samples["rgb"].size(0)):
            rgb = samples["rgb"][j]    # [3, 512, 512]
            swir = samples["swir"][j]  # [1, 512, 512]
            
            # Convert RGB normally (3 channels)
            rgb_img = transforms.ToPILImage()(rgb)
            
            # ✅ CRITICAL FIX: Ensure SWIR is single channel grayscale
            swir_img = transforms.ToPILImage()(swir)  # Force grayscale
            
            img_id = i * BATCH_SIZE + j
            rgb_img.save(f"datasets/rasmd/train_A/{img_id:06d}.jpg")
            swir_img.save(f"datasets/rasmd/train_B/{img_id:06d}.jpg")
        
        if i % 10 == 0:
            print(f"Processed batch {i}/{len(train_loader)}")
            
    # Same fix for validation data
    print("Converting validation data...")
    for i, (samples, targets) in enumerate(val_loader):
        for j in range(samples["rgb"].size(0)):
            rgb = samples["rgb"][j]
            swir = samples["swir"][j]
            
            rgb_img = transforms.ToPILImage()(rgb)
            swir_img = transforms.ToPILImage()(swir)  # ✅ Force grayscale
            
            img_id = i * BATCH_SIZE + j
            rgb_img.save(f"datasets/rasmd/test_A/{img_id:06d}.jpg")
            swir_img.save(f"datasets/rasmd/test_B/{img_id:06d}.jpg")
            
    print("✅ Dataset conversion completed successfully!")

# Run the FIXED conversion
convert_rasmd_to_pix2pixhd_format()
# Out:
# Converting training data...
# Processed batch 0/144
# Processed batch 10/144
# Processed batch 20/144
# Processed batch 30/144
# Processed batch 40/144
# Processed batch 50/144
# Processed batch 60/144
# Processed batch 70/144
# Processed batch 80/144
# Processed batch 90/144
# Processed batch 100/144
# Processed batch 110/144
# Processed batch 120/144
# Processed batch 130/144
# Processed batch 140/144
# Converting validation data...
# ✅ Dataset conversion completed successfully!

# %%
# Check that files were created properly
train_a_files = len(os.listdir("datasets/rasmd/train_A"))
train_b_files = len(os.listdir("datasets/rasmd/train_B"))
test_a_files = len(os.listdir("datasets/rasmd/test_A"))  
test_b_files = len(os.listdir("datasets/rasmd/test_B"))

print(f"✅ Training RGB images: {train_a_files}")
print(f"✅ Training SWIR images: {train_b_files}")
print(f"✅ Test RGB images: {test_a_files}")
print(f"✅ Test SWIR images: {test_b_files}")

# Should be equal pairs
assert train_a_files == train_b_files, "Mismatch in training RGB/SWIR pairs!"
assert test_a_files == test_b_files, "Mismatch in test RGB/SWIR pairs!"
print("✅ All checks passed - ready for Pix2PixHD training!")
# Out:
# ✅ Training RGB images: 1146
# ✅ Training SWIR images: 1146
# ✅ Test RGB images: 286
# ✅ Test SWIR images: 286
# ✅ All checks passed - ready for Pix2PixHD training!

# %%
# In a new cell, copy the uploaded file to replace the old one
import shutil

# Copy your fixed train.py over the original
shutil.copy('/kaggle/input/train1-py/train.py', '/kaggle/working/pix2pixHD/train.py')

print("✅ Successfully replaced train.py with fixed version!")
# Out:
# ✅ Successfully replaced train.py with fixed version!

# %%
# !cd /kaggle/working/pix2pixHD


# !python /kaggle/working/pix2pixHD/train.py \
  --name rasmd_rgb2swir_aligned \
  --dataroot datasets/rasmd\
  --model pix2pixHD \
  --netG global \
  --ngf 32 \
  --num_D 2 \
  --n_layers_D 3 \
  --no_instance \
  --label_nc 0 \
  --loadSize 512 \
  --fineSize 512 \
  --batchSize 8 \
  --niter 100 \
  --niter_decay 50 \
  --save_epoch_freq 10 \
  --display_freq 400 \
  --print_freq 100
# Out:
# ------------ Options -------------
# batchSize: 8
# beta1: 0.5
# checkpoints_dir: ./checkpoints
# continue_train: False
# data_type: 32
# dataroot: datasets/rasmd
# debug: False
# display_freq: 400
# display_winsize: 512
# feat_num: 3
# fineSize: 512
# fp16: False
# gpu_ids: [0]
# input_nc: 3
# instance_feat: False
# isTrain: True
# label_feat: False
# label_nc: 0
# lambda_feat: 10.0
# loadSize: 512
# load_features: False
# load_pretrain:
# local_rank: 0
# lr: 0.0002
# max_dataset_size: inf
# model: pix2pixHD
# nThreads: 2
# n_blocks_global: 9
# n_blocks_local: 3
# n_clusters: 10
# n_downsample_E: 4
# n_downsample_global: 4
# n_layers_D: 3
# n_local_enhancers: 1
# name: rasmd_rgb2swir_aligned
# ndf: 64
# nef: 16
# netG: global
# ngf: 32
# niter: 100
# niter_decay: 50
# niter_fix_global: 0
# no_flip: False
# no_ganFeat_loss: False
# no_html: False
# no_instance: True
# no_lsgan: False
# no_vgg_loss: False
# norm: instance
# num_D: 2
# output_nc: 3
# phase: train
# pool_size: 0
# print_freq: 100
# resize_or_crop: scale_width
# save_epoch_freq: 10
# save_latest_freq: 1000
# serial_batches: False
# tf_log: False
# use_dropout: False
# verbose: False
# which_epoch: latest
# -------------- End ----------------
# CustomDatasetDataLoader
# dataset [AlignedDataset] was created
# #training images = 1144
# GlobalGenerator(
#   (model): Sequential(
#     (0): ReflectionPad2d((3, 3, 3, 3))
#     (1): Conv2d(3, 32, kernel_size=(7, 7), stride=(1, 1))
#     (2): InstanceNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (3): ReLU(inplace=True)
#     (4): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (5): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (6): ReLU(inplace=True)
#     (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (8): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (9): ReLU(inplace=True)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (11): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (12): ReLU(inplace=True)
#     (13): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (14): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (15): ReLU(inplace=True)
#     (16): ResnetBlock(
#       (conv_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#     (17): ResnetBlock(
#       (conv_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#     (18): ResnetBlock(
#       (conv_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#     (19): ResnetBlock(
#       (conv_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#     (20): ResnetBlock(
#       (conv_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#     (21): ResnetBlock(
#       (conv_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#     (22): ResnetBlock(
#       (conv_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#     (23): ResnetBlock(
#       (conv_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#     (24): ResnetBlock(
#       (conv_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#     (25): ConvTranspose2d(512, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (26): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (27): ReLU(inplace=True)
#     (28): ConvTranspose2d(256, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (29): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (30): ReLU(inplace=True)
#     (31): ConvTranspose2d(128, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (32): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (33): ReLU(inplace=True)
#     (34): ConvTranspose2d(64, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (35): InstanceNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (36): ReLU(inplace=True)
#     (37): ReflectionPad2d((3, 3, 3, 3))
#     (38): Conv2d(32, 3, kernel_size=(7, 7), stride=(1, 1))
#     (39): Tanh()
#   )
# )
# MultiscaleDiscriminator(
#   (scale0_layer0): Sequential(
#     (0): Conv2d(6, 64, kernel_size=(4, 4), stride=(2, 2), padding=(2, 2))
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#   )
#   (scale0_layer1): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(2, 2))
#     (1): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (2): LeakyReLU(negative_slope=0.2, inplace=True)
#   )
#   (scale0_layer2): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(2, 2))
#     (1): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (2): LeakyReLU(negative_slope=0.2, inplace=True)
#   )
#   (scale0_layer3): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(1, 1), padding=(2, 2))
#     (1): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (2): LeakyReLU(negative_slope=0.2, inplace=True)
#   )
#   (scale0_layer4): Sequential(
#     (0): Conv2d(512, 1, kernel_size=(4, 4), stride=(1, 1), padding=(2, 2))
#   )
#   (scale1_layer0): Sequential(
#     (0): Conv2d(6, 64, kernel_size=(4, 4), stride=(2, 2), padding=(2, 2))
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#   )
#   (scale1_layer1): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(2, 2))
#     (1): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (2): LeakyReLU(negative_slope=0.2, inplace=True)
#   )
#   (scale1_layer2): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(2, 2))
#     (1): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (2): LeakyReLU(negative_slope=0.2, inplace=True)
#   )
#   (scale1_layer3): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(1, 1), padding=(2, 2))
#     (1): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (2): LeakyReLU(negative_slope=0.2, inplace=True)
#   )
#   (scale1_layer4): Sequential(
#     (0): Conv2d(512, 1, kernel_size=(4, 4), stride=(1, 1), padding=(2, 2))
#   )
#   (downsample): AvgPool2d(kernel_size=3, stride=2, padding=[1, 1])
# )
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG19_Weights.IMAGENET1K_V1`. You can also use `weights=VGG19_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth
# 100%|█████████████████████████████████████████| 548M/548M [00:02<00:00, 212MB/s]
# create web directory ./checkpoints/rasmd_rgb2swir_aligned/web...
# /kaggle/working/pix2pixHD/models/networks.py:95: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /pytorch/torch/csrc/tensor/python_tensor.cpp:78.)
#   fake_tensor = self.Tensor(input.size()).fill_(self.fake_label)
# (epoch: 1, iters: 200, time: 0.358) G_GAN: 2.264 G_GAN_Feat: 6.161 G_VGG: 3.868 D_real: 1.921 D_fake: 2.011
# (epoch: 1, iters: 400, time: 0.156) G_GAN: 1.031 G_GAN_Feat: 4.691 G_VGG: 3.910 D_real: 0.943 D_fake: 0.828
# (epoch: 1, iters: 600, time: 0.156) G_GAN: 0.731 G_GAN_Feat: 5.046 G_VGG: 3.718 D_real: 0.611 D_fake: 0.549
# (epoch: 1, iters: 800, time: 0.156) G_GAN: 0.832 G_GAN_Feat: 4.944 G_VGG: 3.572 D_real: 0.601 D_fake: 0.453
# (epoch: 1, iters: 1000, time: 0.156) G_GAN: 0.848 G_GAN_Feat: 5.046 G_VGG: 3.489 D_real: 0.596 D_fake: 0.451
# saving the latest model (epoch 1, total_steps 1000)
# End of epoch 1 / 150 	 Time Taken: 218 sec
# (epoch: 2, iters: 56, time: 0.156) G_GAN: 0.838 G_GAN_Feat: 2.268 G_VGG: 2.738 D_real: 0.717 D_fake: 0.317
# (epoch: 2, iters: 256, time: 0.156) G_GAN: 0.601 G_GAN_Feat: 2.387 G_VGG: 2.340 D_real: 0.555 D_fake: 0.532
# (epoch: 2, iters: 456, time: 0.156) G_GAN: 0.755 G_GAN_Feat: 3.840 G_VGG: 2.897 D_real: 0.548 D_fake: 0.456
# (epoch: 2, iters: 656, time: 0.156) G_GAN: 0.806 G_GAN_Feat: 3.025 G_VGG: 2.684 D_real: 0.637 D_fake: 0.330
# (epoch: 2, iters: 856, time: 0.156) G_GAN: 0.728 G_GAN_Feat: 4.924 G_VGG: 3.072 D_real: 0.404 D_fake: 0.399
# saving the latest model (epoch 2, total_steps 2000)
# (epoch: 2, iters: 1056, time: 0.156) G_GAN: 0.828 G_GAN_Feat: 4.780 G_VGG: 2.929 D_real: 0.552 D_fake: 0.346
# End of epoch 2 / 150 	 Time Taken: 179 sec
# (epoch: 3, iters: 112, time: 0.156) G_GAN: 0.888 G_GAN_Feat: 5.521 G_VGG: 3.730 D_real: 0.377 D_fake: 0.312
# (epoch: 3, iters: 312, time: 0.156) G_GAN: 0.975 G_GAN_Feat: 6.219 G_VGG: 3.464 D_real: 0.438 D_fake: 0.337
# (epoch: 3, iters: 512, time: 0.156) G_GAN: 0.866 G_GAN_Feat: 3.910 G_VGG: 2.796 D_real: 0.534 D_fake: 0.313
# (epoch: 3, iters: 712, time: 0.156) G_GAN: 0.908 G_GAN_Feat: 3.094 G_VGG: 2.562 D_real: 0.754 D_fake: 0.381
# saving the latest model (epoch 3, total_steps 3000)
# (epoch: 3, iters: 912, time: 0.156) G_GAN: 0.875 G_GAN_Feat: 4.724 G_VGG: 2.828 D_real: 0.503 D_fake: 0.336
# (epoch: 3, iters: 1112, time: 0.156) G_GAN: 0.725 G_GAN_Feat: 4.787 G_VGG: 3.284 D_real: 0.377 D_fake: 0.409
# End of epoch 3 / 150 	 Time Taken: 178 sec
# (epoch: 4, iters: 168, time: 0.156) G_GAN: 0.842 G_GAN_Feat: 2.911 G_VGG: 2.509 D_real: 0.635 D_fake: 0.299
# (epoch: 4, iters: 368, time: 0.156) G_GAN: 0.895 G_GAN_Feat: 3.711 G_VGG: 2.786 D_real: 0.581 D_fake: 0.284
# (epoch: 4, iters: 568, time: 0.156) G_GAN: 0.857 G_GAN_Feat: 4.464 G_VGG: 2.900 D_real: 0.433 D_fake: 0.290
# saving the latest model (epoch 4, total_steps 4000)
# (epoch: 4, iters: 768, time: 0.156) G_GAN: 0.925 G_GAN_Feat: 3.657 G_VGG: 2.754 D_real: 0.660 D_fake: 0.751
# (epoch: 4, iters: 968, time: 0.156) G_GAN: 0.845 G_GAN_Feat: 2.603 G_VGG: 2.507 D_real: 0.602 D_fake: 0.293
# End of epoch 4 / 150 	 Time Taken: 179 sec
# (epoch: 5, iters: 24, time: 0.156) G_GAN: 0.757 G_GAN_Feat: 3.434 G_VGG: 2.912 D_real: 0.461 D_fake: 0.487
# (epoch: 5, iters: 224, time: 0.156) G_GAN: 0.998 G_GAN_Feat: 4.429 G_VGG: 2.815 D_real: 0.481 D_fake: 0.221
# (epoch: 5, iters: 424, time: 0.156) G_GAN: 0.957 G_GAN_Feat: 5.613 G_VGG: 2.908 D_real: 0.463 D_fake: 0.281
# saving the latest model (epoch 5, total_steps 5000)
# (epoch: 5, iters: 624, time: 0.156) G_GAN: 0.767 G_GAN_Feat: 2.919 G_VGG: 2.447 D_real: 0.575 D_fake: 0.334
# (epoch: 5, iters: 824, time: 0.156) G_GAN: 0.515 G_GAN_Feat: 4.240 G_VGG: 2.887 D_real: 0.320 D_fake: 0.539
# (epoch: 5, iters: 1024, time: 0.156) G_GAN: 0.669 G_GAN_Feat: 4.298 G_VGG: 2.899 D_real: 0.333 D_fake: 0.404
# End of epoch 5 / 150 	 Time Taken: 179 sec
# (epoch: 6, iters: 80, time: 0.156) G_GAN: 0.835 G_GAN_Feat: 3.874 G_VGG: 2.710 D_real: 0.414 D_fake: 0.306
# (epoch: 6, iters: 280, time: 0.156) G_GAN: 1.005 G_GAN_Feat: 4.042 G_VGG: 2.684 D_real: 0.443 D_fake: 0.234
# saving the latest model (epoch 6, total_steps 6000)
# (epoch: 6, iters: 480, time: 0.156) G_GAN: 1.223 G_GAN_Feat: 4.838 G_VGG: 2.789 D_real: 0.637 D_fake: 0.199
# (epoch: 6, iters: 680, time: 0.156) G_GAN: 0.725 G_GAN_Feat: 4.861 G_VGG: 3.077 D_real: 0.391 D_fake: 0.391
# (epoch: 6, iters: 880, time: 0.156) G_GAN: 0.823 G_GAN_Feat: 2.735 G_VGG: 2.412 D_real: 0.538 D_fake: 0.355
# (epoch: 6, iters: 1080, time: 0.156) G_GAN: 0.967 G_GAN_Feat: 3.092 G_VGG: 2.420 D_real: 0.666 D_fake: 0.258
# End of epoch 6 / 150 	 Time Taken: 179 sec
# (epoch: 7, iters: 136, time: 0.156) G_GAN: 0.914 G_GAN_Feat: 3.274 G_VGG: 2.532 D_real: 0.558 D_fake: 0.277
# saving the latest model (epoch 7, total_steps 7000)
# (epoch: 7, iters: 336, time: 0.156) G_GAN: 0.875 G_GAN_Feat: 5.609 G_VGG: 3.218 D_real: 0.419 D_fake: 0.304
# (epoch: 7, iters: 536, time: 0.156) G_GAN: 0.996 G_GAN_Feat: 4.135 G_VGG: 2.718 D_real: 0.677 D_fake: 0.256
# (epoch: 7, iters: 736, time: 0.156) G_GAN: 0.727 G_GAN_Feat: 2.757 G_VGG: 2.276 D_real: 0.612 D_fake: 0.459
# (epoch: 7, iters: 936, time: 0.156) G_GAN: 0.636 G_GAN_Feat: 3.132 G_VGG: 2.667 D_real: 0.533 D_fake: 0.442
# (epoch: 7, iters: 1136, time: 0.156) G_GAN: 0.822 G_GAN_Feat: 3.769 G_VGG: 2.602 D_real: 0.446 D_fake: 0.325
# saving the latest model (epoch 7, total_steps 8000)
# End of epoch 7 / 150 	 Time Taken: 179 sec
# (epoch: 8, iters: 192, time: 0.156) G_GAN: 0.827 G_GAN_Feat: 6.231 G_VGG: 2.846 D_real: 0.392 D_fake: 0.479
# (epoch: 8, iters: 392, time: 0.156) G_GAN: 0.734 G_GAN_Feat: 3.974 G_VGG: 2.294 D_real: 0.479 D_fake: 0.413
# (epoch: 8, iters: 592, time: 0.156) G_GAN: 0.722 G_GAN_Feat: 5.967 G_VGG: 2.976 D_real: 0.365 D_fake: 0.399
# (epoch: 8, iters: 792, time: 0.156) G_GAN: 0.965 G_GAN_Feat: 4.201 G_VGG: 2.583 D_real: 0.577 D_fake: 0.487
# (epoch: 8, iters: 992, time: 0.156) G_GAN: 0.811 G_GAN_Feat: 3.838 G_VGG: 2.682 D_real: 0.450 D_fake: 0.331
# saving the latest model (epoch 8, total_steps 9000)
# End of epoch 8 / 150 	 Time Taken: 179 sec
# (epoch: 9, iters: 48, time: 0.156) G_GAN: 0.775 G_GAN_Feat: 3.722 G_VGG: 2.512 D_real: 0.446 D_fake: 0.323
# (epoch: 9, iters: 248, time: 0.156) G_GAN: 0.860 G_GAN_Feat: 2.206 G_VGG: 1.905 D_real: 0.679 D_fake: 0.285
# (epoch: 9, iters: 448, time: 0.156) G_GAN: 0.887 G_GAN_Feat: 6.098 G_VGG: 3.901 D_real: 0.252 D_fake: 0.342
# (epoch: 9, iters: 648, time: 0.156) G_GAN: 0.857 G_GAN_Feat: 2.411 G_VGG: 2.350 D_real: 0.692 D_fake: 0.335
# (epoch: 9, iters: 848, time: 0.156) G_GAN: 0.803 G_GAN_Feat: 4.797 G_VGG: 3.993 D_real: 0.564 D_fake: 0.383
# saving the latest model (epoch 9, total_steps 10000)
# (epoch: 9, iters: 1048, time: 0.156) G_GAN: 0.601 G_GAN_Feat: 6.058 G_VGG: 3.232 D_real: 0.226 D_fake: 0.448
# End of epoch 9 / 150 	 Time Taken: 179 sec
# (epoch: 10, iters: 104, time: 0.156) G_GAN: 0.635 G_GAN_Feat: 2.599 G_VGG: 2.804 D_real: 0.516 D_fake: 0.461
# (epoch: 10, iters: 304, time: 0.156) G_GAN: 1.125 G_GAN_Feat: 3.671 G_VGG: 2.849 D_real: 0.607 D_fake: 0.310
# (epoch: 10, iters: 504, time: 0.156) G_GAN: 0.768 G_GAN_Feat: 4.938 G_VGG: 2.513 D_real: 0.523 D_fake: 0.330
# (epoch: 10, iters: 704, time: 0.156) G_GAN: 0.853 G_GAN_Feat: 4.636 G_VGG: 2.630 D_real: 0.549 D_fake: 0.381
# saving the latest model (epoch 10, total_steps 11000)
# (epoch: 10, iters: 904, time: 0.156) G_GAN: 0.790 G_GAN_Feat: 7.676 G_VGG: 3.475 D_real: 0.365 D_fake: 0.611
# (epoch: 10, iters: 1104, time: 0.156) G_GAN: 0.669 G_GAN_Feat: 3.625 G_VGG: 3.156 D_real: 0.420 D_fake: 0.454
# End of epoch 10 / 150 	 Time Taken: 179 sec
# saving the model at the end of epoch 10, iters 11440
# (epoch: 11, iters: 160, time: 0.163) G_GAN: 0.652 G_GAN_Feat: 3.822 G_VGG: 2.440 D_real: 0.445 D_fake: 0.873
# (epoch: 11, iters: 360, time: 0.156) G_GAN: 0.722 G_GAN_Feat: 4.905 G_VGG: 3.143 D_real: 0.452 D_fake: 0.368
# (epoch: 11, iters: 560, time: 0.156) G_GAN: 0.870 G_GAN_Feat: 4.229 G_VGG: 2.669 D_real: 0.584 D_fake: 0.278
# saving the latest model (epoch 11, total_steps 12000)
# (epoch: 11, iters: 760, time: 0.156) G_GAN: 1.060 G_GAN_Feat: 3.087 G_VGG: 2.571 D_real: 0.770 D_fake: 0.341
# (epoch: 11, iters: 960, time: 0.156) G_GAN: 0.868 G_GAN_Feat: 4.371 G_VGG: 2.426 D_real: 0.597 D_fake: 0.415
# End of epoch 11 / 150 	 Time Taken: 178 sec
# (epoch: 12, iters: 16, time: 0.156) G_GAN: 0.762 G_GAN_Feat: 4.674 G_VGG: 2.366 D_real: 0.486 D_fake: 0.331
# (epoch: 12, iters: 216, time: 0.156) G_GAN: 0.679 G_GAN_Feat: 3.849 G_VGG: 2.449 D_real: 0.473 D_fake: 0.497
# (epoch: 12, iters: 416, time: 0.156) G_GAN: 1.074 G_GAN_Feat: 3.730 G_VGG: 2.411 D_real: 0.894 D_fake: 0.902
# saving the latest model (epoch 12, total_steps 13000)
# (epoch: 12, iters: 616, time: 0.156) G_GAN: 0.524 G_GAN_Feat: 3.377 G_VGG: 2.525 D_real: 0.320 D_fake: 0.536
# (epoch: 12, iters: 816, time: 0.156) G_GAN: 0.918 G_GAN_Feat: 5.213 G_VGG: 3.538 D_real: 0.599 D_fake: 0.546
# (epoch: 12, iters: 1016, time: 0.156) G_GAN: 0.389 G_GAN_Feat: 5.012 G_VGG: 2.943 D_real: 0.265 D_fake: 0.704
# End of epoch 12 / 150 	 Time Taken: 179 sec
# (epoch: 13, iters: 72, time: 0.156) G_GAN: 0.690 G_GAN_Feat: 5.107 G_VGG: 2.837 D_real: 0.468 D_fake: 0.425
# (epoch: 13, iters: 272, time: 0.156) G_GAN: 0.884 G_GAN_Feat: 4.553 G_VGG: 2.910 D_real: 0.554 D_fake: 0.594
# saving the latest model (epoch 13, total_steps 14000)
# (epoch: 13, iters: 472, time: 0.156) G_GAN: 0.793 G_GAN_Feat: 3.329 G_VGG: 2.319 D_real: 0.578 D_fake: 0.398
# (epoch: 13, iters: 672, time: 0.156) G_GAN: 0.866 G_GAN_Feat: 5.955 G_VGG: 2.743 D_real: 0.535 D_fake: 0.332
# (epoch: 13, iters: 872, time: 0.156) G_GAN: 0.824 G_GAN_Feat: 4.723 G_VGG: 2.647 D_real: 0.603 D_fake: 0.506
# (epoch: 13, iters: 1072, time: 0.156) G_GAN: 0.809 G_GAN_Feat: 3.691 G_VGG: 2.229 D_real: 0.601 D_fake: 0.311
# End of epoch 13 / 150 	 Time Taken: 179 sec
# (epoch: 14, iters: 128, time: 0.156) G_GAN: 0.578 G_GAN_Feat: 4.106 G_VGG: 2.686 D_real: 0.322 D_fake: 0.561
# saving the latest model (epoch 14, total_steps 15000)
# (epoch: 14, iters: 328, time: 0.156) G_GAN: 0.716 G_GAN_Feat: 4.211 G_VGG: 2.542 D_real: 0.501 D_fake: 0.380
# (epoch: 14, iters: 528, time: 0.156) G_GAN: 0.813 G_GAN_Feat: 3.067 G_VGG: 2.584 D_real: 0.647 D_fake: 0.727
# (epoch: 14, iters: 728, time: 0.156) G_GAN: 0.646 G_GAN_Feat: 2.700 G_VGG: 2.386 D_real: 0.508 D_fake: 0.415
# (epoch: 14, iters: 928, time: 0.156) G_GAN: 0.643 G_GAN_Feat: 2.518 G_VGG: 2.874 D_real: 0.600 D_fake: 0.416
# (epoch: 14, iters: 1128, time: 0.156) G_GAN: 0.559 G_GAN_Feat: 1.895 G_VGG: 2.270 D_real: 0.531 D_fake: 0.473
# saving the latest model (epoch 14, total_steps 16000)
# End of epoch 14 / 150 	 Time Taken: 180 sec
# (epoch: 15, iters: 184, time: 0.156) G_GAN: 0.585 G_GAN_Feat: 2.962 G_VGG: 2.940 D_real: 0.507 D_fake: 0.449
# (epoch: 15, iters: 384, time: 0.156) G_GAN: 0.631 G_GAN_Feat: 2.705 G_VGG: 2.880 D_real: 0.542 D_fake: 0.413
# (epoch: 15, iters: 584, time: 0.156) G_GAN: 0.500 G_GAN_Feat: 2.165 G_VGG: 2.671 D_real: 0.382 D_fake: 0.527
# (epoch: 15, iters: 784, time: 0.156) G_GAN: 0.479 G_GAN_Feat: 1.711 G_VGG: 2.723 D_real: 0.423 D_fake: 0.569
# (epoch: 15, iters: 984, time: 0.156) G_GAN: 0.710 G_GAN_Feat: 2.609 G_VGG: 2.866 D_real: 0.567 D_fake: 0.380
# saving the latest model (epoch 15, total_steps 17000)
# End of epoch 15 / 150 	 Time Taken: 179 sec
# (epoch: 16, iters: 40, time: 0.156) G_GAN: 0.522 G_GAN_Feat: 1.919 G_VGG: 2.168 D_real: 0.408 D_fake: 0.499
# (epoch: 16, iters: 240, time: 0.156) G_GAN: 0.701 G_GAN_Feat: 2.085 G_VGG: 2.474 D_real: 0.535 D_fake: 0.393
# (epoch: 16, iters: 440, time: 0.156) G_GAN: 0.519 G_GAN_Feat: 2.140 G_VGG: 2.412 D_real: 0.403 D_fake: 0.522
# (epoch: 16, iters: 640, time: 0.156) G_GAN: 0.633 G_GAN_Feat: 2.247 G_VGG: 2.457 D_real: 0.504 D_fake: 0.417
# (epoch: 16, iters: 840, time: 0.156) G_GAN: 0.543 G_GAN_Feat: 2.430 G_VGG: 2.349 D_real: 0.412 D_fake: 0.501
# saving the latest model (epoch 16, total_steps 18000)
# (epoch: 16, iters: 1040, time: 0.156) G_GAN: 0.537 G_GAN_Feat: 2.229 G_VGG: 2.149 D_real: 0.444 D_fake: 0.498
# End of epoch 16 / 150 	 Time Taken: 179 sec
# (epoch: 17, iters: 96, time: 0.156) G_GAN: 0.556 G_GAN_Feat: 2.571 G_VGG: 2.453 D_real: 0.442 D_fake: 0.502
# (epoch: 17, iters: 296, time: 0.156) G_GAN: 0.684 G_GAN_Feat: 3.331 G_VGG: 2.916 D_real: 0.501 D_fake: 0.417
# (epoch: 17, iters: 496, time: 0.156) G_GAN: 0.518 G_GAN_Feat: 3.097 G_VGG: 2.699 D_real: 0.462 D_fake: 0.553
# (epoch: 17, iters: 696, time: 0.156) G_GAN: 0.580 G_GAN_Feat: 3.542 G_VGG: 3.118 D_real: 0.349 D_fake: 0.510
# saving the latest model (epoch 17, total_steps 19000)
# (epoch: 17, iters: 896, time: 0.156) G_GAN: 0.565 G_GAN_Feat: 2.268 G_VGG: 1.842 D_real: 0.448 D_fake: 0.483
# (epoch: 17, iters: 1096, time: 0.156) G_GAN: 0.489 G_GAN_Feat: 2.384 G_VGG: 3.524 D_real: 0.414 D_fake: 0.622
# End of epoch 17 / 150 	 Time Taken: 179 sec
# (epoch: 18, iters: 152, time: 0.156) G_GAN: 0.545 G_GAN_Feat: 2.104 G_VGG: 2.192 D_real: 0.480 D_fake: 0.481
# (epoch: 18, iters: 352, time: 0.156) G_GAN: 0.512 G_GAN_Feat: 3.050 G_VGG: 2.924 D_real: 0.422 D_fake: 0.603
# (epoch: 18, iters: 552, time: 0.156) G_GAN: 0.758 G_GAN_Feat: 3.611 G_VGG: 2.676 D_real: 0.601 D_fake: 0.356
# saving the latest model (epoch 18, total_steps 20000)
# (epoch: 18, iters: 752, time: 0.156) G_GAN: 0.822 G_GAN_Feat: 1.947 G_VGG: 1.699 D_real: 0.731 D_fake: 0.430
# (epoch: 18, iters: 952, time: 0.156) G_GAN: 0.407 G_GAN_Feat: 3.353 G_VGG: 2.811 D_real: 0.334 D_fake: 0.702
# End of epoch 18 / 150 	 Time Taken: 179 sec
# (epoch: 19, iters: 8, time: 0.156) G_GAN: 0.449 G_GAN_Feat: 2.688 G_VGG: 2.428 D_real: 0.376 D_fake: 0.641
# (epoch: 19, iters: 208, time: 0.156) G_GAN: 0.635 G_GAN_Feat: 1.893 G_VGG: 1.919 D_real: 0.526 D_fake: 0.420
# (epoch: 19, iters: 408, time: 0.156) G_GAN: 0.636 G_GAN_Feat: 2.788 G_VGG: 2.261 D_real: 0.494 D_fake: 0.448
# saving the latest model (epoch 19, total_steps 21000)
# (epoch: 19, iters: 608, time: 0.156) G_GAN: 0.725 G_GAN_Feat: 2.260 G_VGG: 2.038 D_real: 0.540 D_fake: 0.363
# (epoch: 19, iters: 808, time: 0.156) G_GAN: 0.810 G_GAN_Feat: 2.057 G_VGG: 1.899 D_real: 0.639 D_fake: 0.408
# (epoch: 19, iters: 1008, time: 0.156) G_GAN: 0.651 G_GAN_Feat: 2.775 G_VGG: 2.536 D_real: 0.538 D_fake: 0.438
# End of epoch 19 / 150 	 Time Taken: 179 sec
# (epoch: 20, iters: 64, time: 0.156) G_GAN: 0.685 G_GAN_Feat: 3.236 G_VGG: 2.474 D_real: 0.547 D_fake: 0.444
# (epoch: 20, iters: 264, time: 0.156) G_GAN: 0.862 G_GAN_Feat: 2.245 G_VGG: 2.284 D_real: 0.649 D_fake: 0.298
# saving the latest model (epoch 20, total_steps 22000)
# (epoch: 20, iters: 464, time: 0.156) G_GAN: 0.734 G_GAN_Feat: 2.817 G_VGG: 2.331 D_real: 0.583 D_fake: 0.431
# (epoch: 20, iters: 664, time: 0.156) G_GAN: 0.881 G_GAN_Feat: 2.657 G_VGG: 2.460 D_real: 0.666 D_fake: 0.318
# (epoch: 20, iters: 864, time: 0.156) G_GAN: 0.754 G_GAN_Feat: 2.068 G_VGG: 1.924 D_real: 0.588 D_fake: 0.360
# (epoch: 20, iters: 1064, time: 0.156) G_GAN: 0.550 G_GAN_Feat: 2.433 G_VGG: 2.281 D_real: 0.428 D_fake: 0.490
# End of epoch 20 / 150 	 Time Taken: 179 sec
# saving the model at the end of epoch 20, iters 22880
# (epoch: 21, iters: 120, time: 0.163) G_GAN: 0.564 G_GAN_Feat: 2.416 G_VGG: 2.264 D_real: 0.404 D_fake: 0.520
# saving the latest model (epoch 21, total_steps 23000)
# (epoch: 21, iters: 320, time: 0.156) G_GAN: 0.531 G_GAN_Feat: 2.238 G_VGG: 1.998 D_real: 0.386 D_fake: 0.533
# (epoch: 21, iters: 520, time: 0.156) G_GAN: 0.700 G_GAN_Feat: 2.209 G_VGG: 2.109 D_real: 0.595 D_fake: 0.479
# (epoch: 21, iters: 720, time: 0.156) G_GAN: 0.546 G_GAN_Feat: 2.041 G_VGG: 1.787 D_real: 0.444 D_fake: 0.527
# (epoch: 21, iters: 920, time: 0.156) G_GAN: 0.375 G_GAN_Feat: 2.769 G_VGG: 2.487 D_real: 0.300 D_fake: 0.752
# (epoch: 21, iters: 1120, time: 0.156) G_GAN: 1.003 G_GAN_Feat: 2.861 G_VGG: 2.265 D_real: 0.845 D_fake: 0.267
# saving the latest model (epoch 21, total_steps 24000)
# End of epoch 21 / 150 	 Time Taken: 179 sec
# (epoch: 22, iters: 176, time: 0.156) G_GAN: 0.668 G_GAN_Feat: 3.406 G_VGG: 2.721 D_real: 0.486 D_fake: 0.568
# (epoch: 22, iters: 376, time: 0.156) G_GAN: 0.568 G_GAN_Feat: 2.468 G_VGG: 2.188 D_real: 0.428 D_fake: 0.497
# (epoch: 22, iters: 576, time: 0.156) G_GAN: 0.548 G_GAN_Feat: 3.758 G_VGG: 3.091 D_real: 0.354 D_fake: 0.605
# (epoch: 22, iters: 776, time: 0.156) G_GAN: 0.474 G_GAN_Feat: 2.708 G_VGG: 2.294 D_real: 0.411 D_fake: 0.575
# (epoch: 22, iters: 976, time: 0.156) G_GAN: 0.682 G_GAN_Feat: 2.367 G_VGG: 2.050 D_real: 0.562 D_fake: 0.394
# saving the latest model (epoch 22, total_steps 25000)
# End of epoch 22 / 150 	 Time Taken: 179 sec
# (epoch: 23, iters: 32, time: 0.156) G_GAN: 0.697 G_GAN_Feat: 2.503 G_VGG: 2.280 D_real: 0.554 D_fake: 0.420
# (epoch: 23, iters: 232, time: 0.156) G_GAN: 0.648 G_GAN_Feat: 3.020 G_VGG: 2.630 D_real: 0.462 D_fake: 0.497
# (epoch: 23, iters: 432, time: 0.156) G_GAN: 0.529 G_GAN_Feat: 2.779 G_VGG: 2.429 D_real: 0.383 D_fake: 0.579
# (epoch: 23, iters: 632, time: 0.156) G_GAN: 0.635 G_GAN_Feat: 3.521 G_VGG: 3.108 D_real: 0.432 D_fake: 0.498
# (epoch: 23, iters: 832, time: 0.156) G_GAN: 0.632 G_GAN_Feat: 2.203 G_VGG: 2.098 D_real: 0.522 D_fake: 0.441
# saving the latest model (epoch 23, total_steps 26000)
# (epoch: 23, iters: 1032, time: 0.156) G_GAN: 0.721 G_GAN_Feat: 3.022 G_VGG: 2.413 D_real: 0.537 D_fake: 0.435
# End of epoch 23 / 150 	 Time Taken: 179 sec
# (epoch: 24, iters: 88, time: 0.156) G_GAN: 0.709 G_GAN_Feat: 2.551 G_VGG: 2.114 D_real: 0.583 D_fake: 0.375
# (epoch: 24, iters: 288, time: 0.156) G_GAN: 0.635 G_GAN_Feat: 2.442 G_VGG: 2.124 D_real: 0.481 D_fake: 0.441
# (epoch: 24, iters: 488, time: 0.156) G_GAN: 0.672 G_GAN_Feat: 2.749 G_VGG: 2.583 D_real: 0.454 D_fake: 0.485
# (epoch: 24, iters: 688, time: 0.156) G_GAN: 0.747 G_GAN_Feat: 2.734 G_VGG: 2.427 D_real: 0.634 D_fake: 0.394
# saving the latest model (epoch 24, total_steps 27000)
# (epoch: 24, iters: 888, time: 0.156) G_GAN: 0.420 G_GAN_Feat: 2.054 G_VGG: 1.788 D_real: 0.345 D_fake: 0.637
# (epoch: 24, iters: 1088, time: 0.156) G_GAN: 0.532 G_GAN_Feat: 2.368 G_VGG: 2.057 D_real: 0.426 D_fake: 0.561
# End of epoch 24 / 150 	 Time Taken: 179 sec
# (epoch: 25, iters: 144, time: 0.156) G_GAN: 0.765 G_GAN_Feat: 2.675 G_VGG: 2.503 D_real: 0.614 D_fake: 0.445
# (epoch: 25, iters: 344, time: 0.156) G_GAN: 0.590 G_GAN_Feat: 2.720 G_VGG: 2.243 D_real: 0.399 D_fake: 0.482
# (epoch: 25, iters: 544, time: 0.156) G_GAN: 0.512 G_GAN_Feat: 2.978 G_VGG: 2.566 D_real: 0.366 D_fake: 0.537
# saving the latest model (epoch 25, total_steps 28000)
# (epoch: 25, iters: 744, time: 0.156) G_GAN: 0.574 G_GAN_Feat: 2.688 G_VGG: 2.354 D_real: 0.496 D_fake: 0.521
# (epoch: 25, iters: 944, time: 0.156) G_GAN: 0.553 G_GAN_Feat: 2.844 G_VGG: 2.559 D_real: 0.470 D_fake: 0.517
# (epoch: 25, iters: 1144, time: 0.156) G_GAN: 0.692 G_GAN_Feat: 2.779 G_VGG: 2.221 D_real: 0.571 D_fake: 0.713
# End of epoch 25 / 150 	 Time Taken: 180 sec
# (epoch: 26, iters: 200, time: 0.156) G_GAN: 0.573 G_GAN_Feat: 2.164 G_VGG: 2.121 D_real: 0.493 D_fake: 0.451
# (epoch: 26, iters: 400, time: 0.156) G_GAN: 0.421 G_GAN_Feat: 2.470 G_VGG: 2.254 D_real: 0.346 D_fake: 0.632
# saving the latest model (epoch 26, total_steps 29000)
# (epoch: 26, iters: 600, time: 0.156) G_GAN: 0.715 G_GAN_Feat: 2.696 G_VGG: 2.216 D_real: 0.544 D_fake: 0.434
# (epoch: 26, iters: 800, time: 0.156) G_GAN: 0.666 G_GAN_Feat: 3.000 G_VGG: 2.680 D_real: 0.435 D_fake: 0.401
# (epoch: 26, iters: 1000, time: 0.156) G_GAN: 0.441 G_GAN_Feat: 2.432 G_VGG: 1.986 D_real: 0.363 D_fake: 0.607
# End of epoch 26 / 150 	 Time Taken: 178 sec
# (epoch: 27, iters: 56, time: 0.156) G_GAN: 0.721 G_GAN_Feat: 2.065 G_VGG: 1.745 D_real: 0.663 D_fake: 0.490
# (epoch: 27, iters: 256, time: 0.156) G_GAN: 0.505 G_GAN_Feat: 2.493 G_VGG: 2.197 D_real: 0.445 D_fake: 0.627
# saving the latest model (epoch 27, total_steps 30000)
# (epoch: 27, iters: 456, time: 0.156) G_GAN: 0.557 G_GAN_Feat: 2.337 G_VGG: 1.878 D_real: 0.447 D_fake: 0.502
# (epoch: 27, iters: 656, time: 0.156) G_GAN: 0.523 G_GAN_Feat: 2.630 G_VGG: 2.298 D_real: 0.421 D_fake: 0.557
# (epoch: 27, iters: 856, time: 0.156) G_GAN: 0.449 G_GAN_Feat: 2.345 G_VGG: 1.950 D_real: 0.381 D_fake: 0.602
# (epoch: 27, iters: 1056, time: 0.156) G_GAN: 1.075 G_GAN_Feat: 2.318 G_VGG: 2.100 D_real: 1.043 D_fake: 1.531
# End of epoch 27 / 150 	 Time Taken: 179 sec
# (epoch: 28, iters: 112, time: 0.156) G_GAN: 0.682 G_GAN_Feat: 1.743 G_VGG: 1.477 D_real: 0.607 D_fake: 0.397
# saving the latest model (epoch 28, total_steps 31000)
# (epoch: 28, iters: 312, time: 0.156) G_GAN: 0.630 G_GAN_Feat: 2.744 G_VGG: 2.393 D_real: 0.461 D_fake: 0.440
# (epoch: 28, iters: 512, time: 0.156) G_GAN: 0.834 G_GAN_Feat: 3.129 G_VGG: 2.349 D_real: 0.644 D_fake: 0.411
# (epoch: 28, iters: 712, time: 0.156) G_GAN: 0.541 G_GAN_Feat: 2.545 G_VGG: 2.167 D_real: 0.374 D_fake: 0.511
# (epoch: 28, iters: 912, time: 0.156) G_GAN: 0.988 G_GAN_Feat: 2.539 G_VGG: 1.916 D_real: 0.834 D_fake: 0.288
# (epoch: 28, iters: 1112, time: 0.156) G_GAN: 0.400 G_GAN_Feat: 2.775 G_VGG: 2.190 D_real: 0.293 D_fake: 0.698
# saving the latest model (epoch 28, total_steps 32000)
# End of epoch 28 / 150 	 Time Taken: 180 sec
# (epoch: 29, iters: 168, time: 0.156) G_GAN: 0.388 G_GAN_Feat: 2.347 G_VGG: 1.786 D_real: 0.315 D_fake: 0.674
# (epoch: 29, iters: 368, time: 0.156) G_GAN: 0.431 G_GAN_Feat: 2.556 G_VGG: 1.995 D_real: 0.358 D_fake: 0.643
# (epoch: 29, iters: 568, time: 0.156) G_GAN: 0.496 G_GAN_Feat: 1.689 G_VGG: 2.196 D_real: 0.438 D_fake: 0.550
# (epoch: 29, iters: 768, time: 0.156) G_GAN: 0.597 G_GAN_Feat: 1.079 G_VGG: 1.941 D_real: 0.575 D_fake: 0.437
# (epoch: 29, iters: 968, time: 0.156) G_GAN: 0.478 G_GAN_Feat: 1.059 G_VGG: 1.900 D_real: 0.453 D_fake: 0.542
# saving the latest model (epoch 29, total_steps 33000)
# End of epoch 29 / 150 	 Time Taken: 179 sec
# (epoch: 30, iters: 24, time: 0.156) G_GAN: 0.644 G_GAN_Feat: 1.421 G_VGG: 2.146 D_real: 0.588 D_fake: 0.582
# (epoch: 30, iters: 224, time: 0.156) G_GAN: 0.583 G_GAN_Feat: 1.458 G_VGG: 2.246 D_real: 0.505 D_fake: 0.453
# (epoch: 30, iters: 424, time: 0.156) G_GAN: 0.524 G_GAN_Feat: 1.046 G_VGG: 1.756 D_real: 0.491 D_fake: 0.504
# (epoch: 30, iters: 624, time: 0.156) G_GAN: 0.476 G_GAN_Feat: 1.251 G_VGG: 1.712 D_real: 0.419 D_fake: 0.552
# (epoch: 30, iters: 824, time: 0.156) G_GAN: 0.531 G_GAN_Feat: 1.614 G_VGG: 1.927 D_real: 0.470 D_fake: 0.514
# saving the latest model (epoch 30, total_steps 34000)
# (epoch: 30, iters: 1024, time: 0.156) G_GAN: 0.510 G_GAN_Feat: 1.037 G_VGG: 1.721 D_real: 0.478 D_fake: 0.564
# End of epoch 30 / 150 	 Time Taken: 179 sec
# saving the model at the end of epoch 30, iters 34320
# (epoch: 31, iters: 80, time: 0.163) G_GAN: 0.687 G_GAN_Feat: 1.196 G_VGG: 1.846 D_real: 0.655 D_fake: 0.473
# (epoch: 31, iters: 280, time: 0.156) G_GAN: 0.481 G_GAN_Feat: 1.005 G_VGG: 1.513 D_real: 0.450 D_fake: 0.539
# (epoch: 31, iters: 480, time: 0.156) G_GAN: 0.533 G_GAN_Feat: 2.736 G_VGG: 2.695 D_real: 0.402 D_fake: 0.486
# (epoch: 31, iters: 680, time: 0.156) G_GAN: 0.563 G_GAN_Feat: 1.713 G_VGG: 2.105 D_real: 0.472 D_fake: 0.514
# saving the latest model (epoch 31, total_steps 35000)
# (epoch: 31, iters: 880, time: 0.156) G_GAN: 0.544 G_GAN_Feat: 1.298 G_VGG: 1.521 D_real: 0.505 D_fake: 0.481
# (epoch: 31, iters: 1080, time: 0.156) G_GAN: 0.703 G_GAN_Feat: 1.580 G_VGG: 1.901 D_real: 0.618 D_fake: 0.387
# End of epoch 31 / 150 	 Time Taken: 178 sec
# (epoch: 32, iters: 136, time: 0.156) G_GAN: 0.629 G_GAN_Feat: 1.704 G_VGG: 1.987 D_real: 0.550 D_fake: 0.431
# (epoch: 32, iters: 336, time: 0.156) G_GAN: 0.578 G_GAN_Feat: 1.611 G_VGG: 1.844 D_real: 0.526 D_fake: 0.487
# (epoch: 32, iters: 536, time: 0.156) G_GAN: 0.455 G_GAN_Feat: 1.708 G_VGG: 1.927 D_real: 0.374 D_fake: 0.567
# saving the latest model (epoch 32, total_steps 36000)
# (epoch: 32, iters: 736, time: 0.156) G_GAN: 0.685 G_GAN_Feat: 1.868 G_VGG: 2.318 D_real: 0.592 D_fake: 0.403
# (epoch: 32, iters: 936, time: 0.156) G_GAN: 1.639 G_GAN_Feat: 1.531 G_VGG: 1.573 D_real: 1.582 D_fake: 1.272
# (epoch: 32, iters: 1136, time: 0.156) G_GAN: 0.649 G_GAN_Feat: 1.162 G_VGG: 1.691 D_real: 0.598 D_fake: 0.419
# End of epoch 32 / 150 	 Time Taken: 179 sec
# (epoch: 33, iters: 192, time: 0.156) G_GAN: 0.635 G_GAN_Feat: 1.576 G_VGG: 2.238 D_real: 0.591 D_fake: 0.424
# (epoch: 33, iters: 392, time: 0.156) G_GAN: 0.534 G_GAN_Feat: 1.230 G_VGG: 1.754 D_real: 0.502 D_fake: 0.517
# saving the latest model (epoch 33, total_steps 37000)
# (epoch: 33, iters: 592, time: 0.156) G_GAN: 0.676 G_GAN_Feat: 0.939 G_VGG: 1.331 D_real: 0.628 D_fake: 0.434
# (epoch: 33, iters: 792, time: 0.156) G_GAN: 0.390 G_GAN_Feat: 1.692 G_VGG: 2.080 D_real: 0.333 D_fake: 0.697
# (epoch: 33, iters: 992, time: 0.156) G_GAN: 0.579 G_GAN_Feat: 1.605 G_VGG: 2.171 D_real: 0.500 D_fake: 0.470
# End of epoch 33 / 150 	 Time Taken: 179 sec
# (epoch: 34, iters: 48, time: 0.156) G_GAN: 0.619 G_GAN_Feat: 1.524 G_VGG: 2.065 D_real: 0.555 D_fake: 0.434
# (epoch: 34, iters: 248, time: 0.156) G_GAN: 0.505 G_GAN_Feat: 1.571 G_VGG: 1.943 D_real: 0.448 D_fake: 0.526
# saving the latest model (epoch 34, total_steps 38000)
# (epoch: 34, iters: 448, time: 0.156) G_GAN: 0.344 G_GAN_Feat: 2.153 G_VGG: 2.088 D_real: 0.321 D_fake: 0.877
# (epoch: 34, iters: 648, time: 0.156) G_GAN: 0.496 G_GAN_Feat: 1.548 G_VGG: 2.613 D_real: 0.439 D_fake: 0.551
# (epoch: 34, iters: 848, time: 0.156) G_GAN: 0.533 G_GAN_Feat: 0.944 G_VGG: 1.629 D_real: 0.507 D_fake: 0.487
# (epoch: 34, iters: 1048, time: 0.156) G_GAN: 0.575 G_GAN_Feat: 1.451 G_VGG: 1.845 D_real: 0.498 D_fake: 0.464
# End of epoch 34 / 150 	 Time Taken: 179 sec
# (epoch: 35, iters: 104, time: 0.156) G_GAN: 0.637 G_GAN_Feat: 1.851 G_VGG: 2.515 D_real: 0.542 D_fake: 0.442
# saving the latest model (epoch 35, total_steps 39000)
# (epoch: 35, iters: 304, time: 0.156) G_GAN: 0.440 G_GAN_Feat: 1.503 G_VGG: 1.894 D_real: 0.398 D_fake: 0.640
# (epoch: 35, iters: 504, time: 0.156) G_GAN: 0.507 G_GAN_Feat: 1.404 G_VGG: 1.693 D_real: 0.457 D_fake: 0.518
# (epoch: 35, iters: 704, time: 0.156) G_GAN: 0.487 G_GAN_Feat: 1.501 G_VGG: 1.641 D_real: 0.469 D_fake: 0.794
# (epoch: 35, iters: 904, time: 0.156) G_GAN: 0.577 G_GAN_Feat: 1.395 G_VGG: 1.580 D_real: 0.545 D_fake: 0.456
# (epoch: 35, iters: 1104, time: 0.156) G_GAN: 0.486 G_GAN_Feat: 2.064 G_VGG: 2.156 D_real: 0.406 D_fake: 0.558
# saving the latest model (epoch 35, total_steps 40000)
# End of epoch 35 / 150 	 Time Taken: 180 sec
# (epoch: 36, iters: 160, time: 0.156) G_GAN: 0.637 G_GAN_Feat: 1.434 G_VGG: 1.872 D_real: 0.585 D_fake: 0.588
# (epoch: 36, iters: 360, time: 0.156) G_GAN: 0.577 G_GAN_Feat: 1.610 G_VGG: 1.748 D_real: 0.520 D_fake: 0.469
# (epoch: 36, iters: 560, time: 0.156) G_GAN: 0.535 G_GAN_Feat: 1.454 G_VGG: 1.428 D_real: 0.469 D_fake: 0.492
# (epoch: 36, iters: 760, time: 0.156) G_GAN: 0.581 G_GAN_Feat: 1.706 G_VGG: 1.972 D_real: 0.520 D_fake: 0.491
# (epoch: 36, iters: 960, time: 0.156) G_GAN: 0.570 G_GAN_Feat: 1.611 G_VGG: 1.726 D_real: 0.497 D_fake: 0.477
# saving the latest model (epoch 36, total_steps 41000)
# End of epoch 36 / 150 	 Time Taken: 179 sec
# (epoch: 37, iters: 16, time: 0.156) G_GAN: 0.550 G_GAN_Feat: 1.273 G_VGG: 1.534 D_real: 0.495 D_fake: 0.493
# (epoch: 37, iters: 216, time: 0.156) G_GAN: 0.480 G_GAN_Feat: 1.500 G_VGG: 1.866 D_real: 0.455 D_fake: 0.615
# (epoch: 37, iters: 416, time: 0.156) G_GAN: 0.521 G_GAN_Feat: 1.343 G_VGG: 1.732 D_real: 0.491 D_fake: 0.603
# (epoch: 37, iters: 616, time: 0.156) G_GAN: 0.474 G_GAN_Feat: 1.665 G_VGG: 1.709 D_real: 0.450 D_fake: 0.581
# (epoch: 37, iters: 816, time: 0.156) G_GAN: 0.635 G_GAN_Feat: 2.751 G_VGG: 2.963 D_real: 0.512 D_fake: 0.572
# saving the latest model (epoch 37, total_steps 42000)
# (epoch: 37, iters: 1016, time: 0.156) G_GAN: 0.503 G_GAN_Feat: 1.559 G_VGG: 1.856 D_real: 0.461 D_fake: 0.532
# End of epoch 37 / 150 	 Time Taken: 179 sec
# (epoch: 38, iters: 72, time: 0.156) G_GAN: 0.549 G_GAN_Feat: 2.228 G_VGG: 2.223 D_real: 0.411 D_fake: 0.541
# (epoch: 38, iters: 272, time: 0.156) G_GAN: 0.592 G_GAN_Feat: 1.744 G_VGG: 1.914 D_real: 0.550 D_fake: 0.441
# (epoch: 38, iters: 472, time: 0.156) G_GAN: 0.544 G_GAN_Feat: 2.071 G_VGG: 2.188 D_real: 0.485 D_fake: 0.488
# (epoch: 38, iters: 672, time: 0.156) G_GAN: 0.691 G_GAN_Feat: 1.639 G_VGG: 1.815 D_real: 0.592 D_fake: 0.388
# saving the latest model (epoch 38, total_steps 43000)
# (epoch: 38, iters: 872, time: 0.156) G_GAN: 0.436 G_GAN_Feat: 1.763 G_VGG: 1.719 D_real: 0.437 D_fake: 0.639
# (epoch: 38, iters: 1072, time: 0.156) G_GAN: 0.555 G_GAN_Feat: 1.970 G_VGG: 2.014 D_real: 0.530 D_fake: 0.565
# End of epoch 38 / 150 	 Time Taken: 179 sec
# (epoch: 39, iters: 128, time: 0.156) G_GAN: 0.605 G_GAN_Feat: 1.377 G_VGG: 1.361 D_real: 0.520 D_fake: 0.502
# (epoch: 39, iters: 328, time: 0.156) G_GAN: 0.495 G_GAN_Feat: 1.781 G_VGG: 1.914 D_real: 0.444 D_fake: 0.545
# (epoch: 39, iters: 528, time: 0.156) G_GAN: 0.585 G_GAN_Feat: 1.687 G_VGG: 1.715 D_real: 0.549 D_fake: 0.512
# saving the latest model (epoch 39, total_steps 44000)
# (epoch: 39, iters: 728, time: 0.156) G_GAN: 0.589 G_GAN_Feat: 2.119 G_VGG: 2.127 D_real: 0.535 D_fake: 0.451
# (epoch: 39, iters: 928, time: 0.156) G_GAN: 0.651 G_GAN_Feat: 1.717 G_VGG: 1.788 D_real: 0.605 D_fake: 0.417
# (epoch: 39, iters: 1128, time: 0.156) G_GAN: 0.502 G_GAN_Feat: 3.792 G_VGG: 3.285 D_real: 0.386 D_fake: 0.544
# End of epoch 39 / 150 	 Time Taken: 179 sec
# (epoch: 40, iters: 184, time: 0.156) G_GAN: 0.620 G_GAN_Feat: 1.834 G_VGG: 2.107 D_real: 0.519 D_fake: 0.437
# (epoch: 40, iters: 384, time: 0.156) G_GAN: 0.564 G_GAN_Feat: 1.606 G_VGG: 1.608 D_real: 0.481 D_fake: 0.495
# saving the latest model (epoch 40, total_steps 45000)
# (epoch: 40, iters: 584, time: 0.156) G_GAN: 0.473 G_GAN_Feat: 1.865 G_VGG: 2.302 D_real: 0.447 D_fake: 0.890
# (epoch: 40, iters: 784, time: 0.156) G_GAN: 0.779 G_GAN_Feat: 1.759 G_VGG: 1.639 D_real: 0.638 D_fake: 0.337
# (epoch: 40, iters: 984, time: 0.156) G_GAN: 0.458 G_GAN_Feat: 1.995 G_VGG: 2.138 D_real: 0.356 D_fake: 0.574
# End of epoch 40 / 150 	 Time Taken: 179 sec
# saving the model at the end of epoch 40, iters 45760
# (epoch: 41, iters: 40, time: 0.163) G_GAN: 0.517 G_GAN_Feat: 2.519 G_VGG: 2.325 D_real: 0.431 D_fake: 0.508
# (epoch: 41, iters: 240, time: 0.156) G_GAN: 0.664 G_GAN_Feat: 1.581 G_VGG: 1.600 D_real: 0.609 D_fake: 0.636
# saving the latest model (epoch 41, total_steps 46000)
# (epoch: 41, iters: 440, time: 0.156) G_GAN: 0.780 G_GAN_Feat: 1.374 G_VGG: 1.410 D_real: 0.696 D_fake: 0.446
# (epoch: 41, iters: 640, time: 0.156) G_GAN: 0.544 G_GAN_Feat: 3.591 G_VGG: 2.501 D_real: 0.390 D_fake: 0.510
# (epoch: 41, iters: 840, time: 0.156) G_GAN: 0.664 G_GAN_Feat: 2.078 G_VGG: 2.040 D_real: 0.571 D_fake: 0.417
# (epoch: 41, iters: 1040, time: 0.156) G_GAN: 0.659 G_GAN_Feat: 2.047 G_VGG: 2.025 D_real: 0.544 D_fake: 0.412
# End of epoch 41 / 150 	 Time Taken: 179 sec
# (epoch: 42, iters: 96, time: 0.156) G_GAN: 0.565 G_GAN_Feat: 1.755 G_VGG: 1.601 D_real: 0.489 D_fake: 0.465
# saving the latest model (epoch 42, total_steps 47000)
# (epoch: 42, iters: 296, time: 0.156) G_GAN: 0.796 G_GAN_Feat: 1.505 G_VGG: 1.590 D_real: 0.748 D_fake: 0.327
# (epoch: 42, iters: 496, time: 0.156) G_GAN: 0.557 G_GAN_Feat: 1.939 G_VGG: 2.026 D_real: 0.455 D_fake: 0.542
# (epoch: 42, iters: 696, time: 0.156) G_GAN: 0.603 G_GAN_Feat: 1.798 G_VGG: 1.506 D_real: 0.489 D_fake: 0.431
# (epoch: 42, iters: 896, time: 0.156) G_GAN: 0.685 G_GAN_Feat: 1.678 G_VGG: 1.652 D_real: 0.584 D_fake: 0.377
# (epoch: 42, iters: 1096, time: 0.156) G_GAN: 0.629 G_GAN_Feat: 1.982 G_VGG: 1.880 D_real: 0.498 D_fake: 0.421
# saving the latest model (epoch 42, total_steps 48000)
# End of epoch 42 / 150 	 Time Taken: 180 sec
# (epoch: 43, iters: 152, time: 0.156) G_GAN: 0.704 G_GAN_Feat: 1.838 G_VGG: 1.827 D_real: 0.594 D_fake: 0.417
# (epoch: 43, iters: 352, time: 0.156) G_GAN: 4.825 G_GAN_Feat: 0.761 G_VGG: 1.817 D_real: 4.805 D_fake: 4.529
# (epoch: 43, iters: 552, time: 0.156) G_GAN: 0.508 G_GAN_Feat: 0.798 G_VGG: 2.075 D_real: 0.483 D_fake: 0.541
# (epoch: 43, iters: 752, time: 0.156) G_GAN: 0.527 G_GAN_Feat: 0.739 G_VGG: 1.741 D_real: 0.503 D_fake: 0.600
# (epoch: 43, iters: 952, time: 0.156) G_GAN: 0.536 G_GAN_Feat: 0.849 G_VGG: 1.878 D_real: 0.513 D_fake: 0.495
# saving the latest model (epoch 43, total_steps 49000)
# End of epoch 43 / 150 	 Time Taken: 179 sec
# (epoch: 44, iters: 8, time: 0.156) G_GAN: 0.441 G_GAN_Feat: 0.952 G_VGG: 1.769 D_real: 0.423 D_fake: 0.573
# (epoch: 44, iters: 208, time: 0.156) G_GAN: 0.511 G_GAN_Feat: 0.908 G_VGG: 2.055 D_real: 0.483 D_fake: 0.516
# (epoch: 44, iters: 408, time: 0.156) G_GAN: 0.505 G_GAN_Feat: 0.993 G_VGG: 1.790 D_real: 0.478 D_fake: 0.505
# (epoch: 44, iters: 608, time: 0.156) G_GAN: 0.530 G_GAN_Feat: 0.716 G_VGG: 1.628 D_real: 0.509 D_fake: 0.481
# (epoch: 44, iters: 808, time: 0.156) G_GAN: 0.584 G_GAN_Feat: 0.610 G_VGG: 1.384 D_real: 0.566 D_fake: 0.470
# saving the latest model (epoch 44, total_steps 50000)
# (epoch: 44, iters: 1008, time: 0.156) G_GAN: 0.565 G_GAN_Feat: 0.693 G_VGG: 1.196 D_real: 0.547 D_fake: 0.456
# End of epoch 44 / 150 	 Time Taken: 179 sec
# (epoch: 45, iters: 64, time: 0.156) G_GAN: 0.489 G_GAN_Feat: 0.826 G_VGG: 1.567 D_real: 0.469 D_fake: 0.540
# (epoch: 45, iters: 264, time: 0.156) G_GAN: 0.700 G_GAN_Feat: 1.006 G_VGG: 1.686 D_real: 0.640 D_fake: 0.387
# (epoch: 45, iters: 464, time: 0.156) G_GAN: 0.726 G_GAN_Feat: 0.797 G_VGG: 1.534 D_real: 0.699 D_fake: 0.397
# (epoch: 45, iters: 664, time: 0.156) G_GAN: 0.518 G_GAN_Feat: 0.926 G_VGG: 1.598 D_real: 0.485 D_fake: 0.494
# saving the latest model (epoch 45, total_steps 51000)
# (epoch: 45, iters: 864, time: 0.156) G_GAN: 0.507 G_GAN_Feat: 1.094 G_VGG: 1.683 D_real: 0.471 D_fake: 0.536
# (epoch: 45, iters: 1064, time: 0.156) G_GAN: 0.467 G_GAN_Feat: 0.900 G_VGG: 1.319 D_real: 0.428 D_fake: 0.604
# End of epoch 45 / 150 	 Time Taken: 179 sec
# (epoch: 46, iters: 120, time: 0.156) G_GAN: 0.516 G_GAN_Feat: 0.906 G_VGG: 1.314 D_real: 0.479 D_fake: 0.494
# (epoch: 46, iters: 320, time: 0.156) G_GAN: 0.780 G_GAN_Feat: 1.463 G_VGG: 1.810 D_real: 0.702 D_fake: 0.319
# (epoch: 46, iters: 520, time: 0.156) G_GAN: 0.619 G_GAN_Feat: 1.244 G_VGG: 1.438 D_real: 0.566 D_fake: 0.431
# saving the latest model (epoch 46, total_steps 52000)
# (epoch: 46, iters: 720, time: 0.156) G_GAN: 0.593 G_GAN_Feat: 1.575 G_VGG: 2.120 D_real: 0.501 D_fake: 0.491
# (epoch: 46, iters: 920, time: 0.156) G_GAN: 0.651 G_GAN_Feat: 1.431 G_VGG: 1.622 D_real: 0.591 D_fake: 0.415
# (epoch: 46, iters: 1120, time: 0.156) G_GAN: 0.498 G_GAN_Feat: 1.744 G_VGG: 1.961 D_real: 0.439 D_fake: 0.559
# End of epoch 46 / 150 	 Time Taken: 179 sec
# (epoch: 47, iters: 176, time: 0.156) G_GAN: 0.585 G_GAN_Feat: 1.654 G_VGG: 1.597 D_real: 0.516 D_fake: 0.503
# (epoch: 47, iters: 376, time: 0.156) G_GAN: 0.599 G_GAN_Feat: 1.946 G_VGG: 2.099 D_real: 0.471 D_fake: 0.431
# saving the latest model (epoch 47, total_steps 53000)
# (epoch: 47, iters: 576, time: 0.156) G_GAN: 0.882 G_GAN_Feat: 1.528 G_VGG: 1.648 D_real: 0.797 D_fake: 0.270
# (epoch: 47, iters: 776, time: 0.156) G_GAN: 0.739 G_GAN_Feat: 1.646 G_VGG: 1.548 D_real: 0.627 D_fake: 0.333
# (epoch: 47, iters: 976, time: 0.156) G_GAN: 0.667 G_GAN_Feat: 2.748 G_VGG: 2.184 D_real: 0.594 D_fake: 0.397
# End of epoch 47 / 150 	 Time Taken: 179 sec
# (epoch: 48, iters: 32, time: 0.156) G_GAN: 0.687 G_GAN_Feat: 1.986 G_VGG: 2.203 D_real: 0.626 D_fake: 0.385
# (epoch: 48, iters: 232, time: 0.156) G_GAN: 0.450 G_GAN_Feat: 1.809 G_VGG: 1.556 D_real: 0.359 D_fake: 0.669
# saving the latest model (epoch 48, total_steps 54000)
# (epoch: 48, iters: 432, time: 0.156) G_GAN: 0.684 G_GAN_Feat: 2.102 G_VGG: 1.843 D_real: 0.579 D_fake: 0.367
# (epoch: 48, iters: 632, time: 0.156) G_GAN: 0.899 G_GAN_Feat: 2.368 G_VGG: 1.951 D_real: 0.801 D_fake: 0.426
# (epoch: 48, iters: 832, time: 0.156) G_GAN: 0.826 G_GAN_Feat: 2.161 G_VGG: 2.133 D_real: 0.665 D_fake: 0.394
# (epoch: 48, iters: 1032, time: 0.156) G_GAN: 0.502 G_GAN_Feat: 2.010 G_VGG: 1.488 D_real: 0.453 D_fake: 0.543
# End of epoch 48 / 150 	 Time Taken: 179 sec
# (epoch: 49, iters: 88, time: 0.156) G_GAN: 0.445 G_GAN_Feat: 2.631 G_VGG: 1.887 D_real: 0.376 D_fake: 0.615
# saving the latest model (epoch 49, total_steps 55000)
# (epoch: 49, iters: 288, time: 0.156) G_GAN: 0.540 G_GAN_Feat: 2.044 G_VGG: 1.561 D_real: 0.493 D_fake: 0.484
# (epoch: 49, iters: 488, time: 0.156) G_GAN: 0.489 G_GAN_Feat: 2.646 G_VGG: 2.036 D_real: 0.340 D_fake: 0.562
# (epoch: 49, iters: 688, time: 0.156) G_GAN: 0.540 G_GAN_Feat: 2.313 G_VGG: 1.790 D_real: 0.495 D_fake: 0.504
# (epoch: 49, iters: 888, time: 0.156) G_GAN: 0.574 G_GAN_Feat: 2.498 G_VGG: 2.157 D_real: 0.467 D_fake: 0.458
# (epoch: 49, iters: 1088, time: 0.156) G_GAN: 0.381 G_GAN_Feat: 3.496 G_VGG: 2.346 D_real: 0.358 D_fake: 0.780
# saving the latest model (epoch 49, total_steps 56000)
# End of epoch 49 / 150 	 Time Taken: 180 sec
# (epoch: 50, iters: 144, time: 0.156) G_GAN: 0.473 G_GAN_Feat: 2.057 G_VGG: 1.682 D_real: 0.442 D_fake: 0.583
# (epoch: 50, iters: 344, time: 0.156) G_GAN: 0.543 G_GAN_Feat: 3.094 G_VGG: 2.179 D_real: 0.413 D_fake: 0.519
# (epoch: 50, iters: 544, time: 0.156) G_GAN: 0.948 G_GAN_Feat: 2.816 G_VGG: 2.563 D_real: 0.771 D_fake: 0.395
# (epoch: 50, iters: 744, time: 0.156) G_GAN: 0.557 G_GAN_Feat: 1.746 G_VGG: 2.001 D_real: 0.474 D_fake: 0.471
# ...
# End of epoch 129 / 150 	 Time Taken: 179 sec
# (epoch: 130, iters: 24, time: 0.156) G_GAN: 0.562 G_GAN_Feat: 2.443 G_VGG: 1.293 D_real: 0.467 D_fake: 0.461
# (epoch: 130, iters: 224, time: 0.156) G_GAN: 0.330 G_GAN_Feat: 2.267 G_VGG: 1.319 D_real: 0.266 D_fake: 0.767
# (epoch: 130, iters: 424, time: 0.156) G_GAN: 0.683 G_GAN_Feat: 1.730 G_VGG: 1.036 D_real: 0.626 D_fake: 0.389
# saving the latest model (epoch 130, total_steps 148000)
# (epoch: 130, iters: 624, time: 0.156) G_GAN: 0.483 G_GAN_Feat: 1.778 G_VGG: 0.904 D_real: 0.425 D_fake: 0.548
# (epoch: 130, iters: 824, time: 0.156) G_GAN: 0.514 G_GAN_Feat: 2.467 G_VGG: 1.278 D_real: 0.374 D_fake: 0.509
# (epoch: 130, iters: 1024, time: 0.156) G_GAN: 0.599 G_GAN_Feat: 2.644 G_VGG: 1.798 D_real: 0.451 D_fake: 0.441
# End of epoch 130 / 150 	 Time Taken: 179 sec
# saving the model at the end of epoch 130, iters 148720
# (epoch: 131, iters: 80, time: 0.164) G_GAN: 0.562 G_GAN_Feat: 2.387 G_VGG: 1.365 D_real: 0.451 D_fake: 0.467
# (epoch: 131, iters: 280, time: 0.156) G_GAN: 0.616 G_GAN_Feat: 2.347 G_VGG: 1.299 D_real: 0.497 D_fake: 0.417
# saving the latest model (epoch 131, total_steps 149000)
# (epoch: 131, iters: 480, time: 0.156) G_GAN: 0.601 G_GAN_Feat: 2.287 G_VGG: 1.537 D_real: 0.509 D_fake: 0.473
# (epoch: 131, iters: 680, time: 0.156) G_GAN: 0.715 G_GAN_Feat: 2.345 G_VGG: 1.218 D_real: 0.580 D_fake: 0.355
# (epoch: 131, iters: 880, time: 0.156) G_GAN: 0.469 G_GAN_Feat: 2.098 G_VGG: 1.065 D_real: 0.387 D_fake: 0.554
# (epoch: 131, iters: 1080, time: 0.156) G_GAN: 0.433 G_GAN_Feat: 2.358 G_VGG: 1.127 D_real: 0.373 D_fake: 0.626
# End of epoch 131 / 150 	 Time Taken: 179 sec
# (epoch: 132, iters: 136, time: 0.156) G_GAN: 0.509 G_GAN_Feat: 1.979 G_VGG: 1.180 D_real: 0.438 D_fake: 0.509
# saving the latest model (epoch 132, total_steps 150000)
# (epoch: 132, iters: 336, time: 0.156) G_GAN: 0.622 G_GAN_Feat: 2.189 G_VGG: 1.047 D_real: 0.514 D_fake: 0.419
# (epoch: 132, iters: 536, time: 0.156) G_GAN: 0.485 G_GAN_Feat: 2.250 G_VGG: 1.215 D_real: 0.435 D_fake: 0.550
# (epoch: 132, iters: 736, time: 0.156) G_GAN: 0.711 G_GAN_Feat: 2.231 G_VGG: 1.273 D_real: 0.613 D_fake: 0.363
# (epoch: 132, iters: 936, time: 0.156) G_GAN: 0.537 G_GAN_Feat: 1.980 G_VGG: 1.219 D_real: 0.451 D_fake: 0.487
# (epoch: 132, iters: 1136, time: 0.156) G_GAN: 0.708 G_GAN_Feat: 2.044 G_VGG: 1.198 D_real: 0.632 D_fake: 0.348
# saving the latest model (epoch 132, total_steps 151000)
# End of epoch 132 / 150 	 Time Taken: 180 sec
# (epoch: 133, iters: 192, time: 0.156) G_GAN: 0.523 G_GAN_Feat: 2.231 G_VGG: 1.300 D_real: 0.426 D_fake: 0.500
# (epoch: 133, iters: 392, time: 0.156) G_GAN: 0.584 G_GAN_Feat: 2.156 G_VGG: 1.124 D_real: 0.455 D_fake: 0.458
# (epoch: 133, iters: 592, time: 0.156) G_GAN: 0.506 G_GAN_Feat: 2.495 G_VGG: 1.503 D_real: 0.424 D_fake: 0.529
# (epoch: 133, iters: 792, time: 0.156) G_GAN: 0.613 G_GAN_Feat: 2.202 G_VGG: 1.124 D_real: 0.511 D_fake: 0.419
# (epoch: 133, iters: 992, time: 0.156) G_GAN: 0.589 G_GAN_Feat: 2.689 G_VGG: 1.787 D_real: 0.457 D_fake: 0.462
# saving the latest model (epoch 133, total_steps 152000)
# End of epoch 133 / 150 	 Time Taken: 179 sec
# (epoch: 134, iters: 48, time: 0.156) G_GAN: 0.578 G_GAN_Feat: 2.081 G_VGG: 0.887 D_real: 0.495 D_fake: 0.461
# (epoch: 134, iters: 248, time: 0.156) G_GAN: 0.732 G_GAN_Feat: 2.132 G_VGG: 1.295 D_real: 0.644 D_fake: 0.358
# (epoch: 134, iters: 448, time: 0.156) G_GAN: 0.698 G_GAN_Feat: 2.425 G_VGG: 1.294 D_real: 0.561 D_fake: 0.364
# (epoch: 134, iters: 648, time: 0.156) G_GAN: 0.580 G_GAN_Feat: 2.326 G_VGG: 1.226 D_real: 0.478 D_fake: 0.465
# (epoch: 134, iters: 848, time: 0.156) G_GAN: 0.716 G_GAN_Feat: 2.518 G_VGG: 1.679 D_real: 0.589 D_fake: 0.352
# saving the latest model (epoch 134, total_steps 153000)
# (epoch: 134, iters: 1048, time: 0.156) G_GAN: 0.720 G_GAN_Feat: 2.143 G_VGG: 1.298 D_real: 0.606 D_fake: 0.347
# End of epoch 134 / 150 	 Time Taken: 179 sec
# (epoch: 135, iters: 104, time: 0.156) G_GAN: 0.456 G_GAN_Feat: 2.659 G_VGG: 1.292 D_real: 0.362 D_fake: 0.576
# (epoch: 135, iters: 304, time: 0.156) G_GAN: 0.678 G_GAN_Feat: 2.034 G_VGG: 1.119 D_real: 0.560 D_fake: 0.412
# (epoch: 135, iters: 504, time: 0.156) G_GAN: 0.574 G_GAN_Feat: 2.340 G_VGG: 1.279 D_real: 0.473 D_fake: 0.457
# (epoch: 135, iters: 704, time: 0.156) G_GAN: 0.606 G_GAN_Feat: 2.273 G_VGG: 0.966 D_real: 0.501 D_fake: 0.439
# saving the latest model (epoch 135, total_steps 154000)
# (epoch: 135, iters: 904, time: 0.156) G_GAN: 0.542 G_GAN_Feat: 2.374 G_VGG: 1.165 D_real: 0.418 D_fake: 0.513
# (epoch: 135, iters: 1104, time: 0.156) G_GAN: 0.589 G_GAN_Feat: 2.543 G_VGG: 1.165 D_real: 0.471 D_fake: 0.445
# End of epoch 135 / 150 	 Time Taken: 179 sec
# (epoch: 136, iters: 160, time: 0.156) G_GAN: 0.535 G_GAN_Feat: 2.436 G_VGG: 1.126 D_real: 0.437 D_fake: 0.491
# (epoch: 136, iters: 360, time: 0.156) G_GAN: 0.528 G_GAN_Feat: 2.451 G_VGG: 1.073 D_real: 0.432 D_fake: 0.503
# (epoch: 136, iters: 560, time: 0.156) G_GAN: 0.535 G_GAN_Feat: 2.848 G_VGG: 1.597 D_real: 0.447 D_fake: 0.558
# saving the latest model (epoch 136, total_steps 155000)
# (epoch: 136, iters: 760, time: 0.156) G_GAN: 0.699 G_GAN_Feat: 2.747 G_VGG: 1.466 D_real: 0.553 D_fake: 0.369
# (epoch: 136, iters: 960, time: 0.156) G_GAN: 0.758 G_GAN_Feat: 1.379 G_VGG: 0.968 D_real: 0.743 D_fake: 0.383
# End of epoch 136 / 150 	 Time Taken: 179 sec
# (epoch: 137, iters: 16, time: 0.156) G_GAN: 0.534 G_GAN_Feat: 1.499 G_VGG: 1.199 D_real: 0.509 D_fake: 0.480
# (epoch: 137, iters: 216, time: 0.156) G_GAN: 0.525 G_GAN_Feat: 1.589 G_VGG: 1.109 D_real: 0.497 D_fake: 0.486
# (epoch: 137, iters: 416, time: 0.156) G_GAN: 0.501 G_GAN_Feat: 1.439 G_VGG: 1.015 D_real: 0.479 D_fake: 0.509
# saving the latest model (epoch 137, total_steps 156000)
# (epoch: 137, iters: 616, time: 0.156) G_GAN: 0.482 G_GAN_Feat: 1.573 G_VGG: 1.078 D_real: 0.457 D_fake: 0.529
# (epoch: 137, iters: 816, time: 0.156) G_GAN: 0.478 G_GAN_Feat: 2.057 G_VGG: 1.426 D_real: 0.440 D_fake: 0.537
# (epoch: 137, iters: 1016, time: 0.156) G_GAN: 0.588 G_GAN_Feat: 1.867 G_VGG: 1.285 D_real: 0.540 D_fake: 0.434
# End of epoch 137 / 150 	 Time Taken: 179 sec
# (epoch: 138, iters: 72, time: 0.156) G_GAN: 0.511 G_GAN_Feat: 1.835 G_VGG: 1.140 D_real: 0.463 D_fake: 0.504
# (epoch: 138, iters: 272, time: 0.156) G_GAN: 0.538 G_GAN_Feat: 2.098 G_VGG: 1.288 D_real: 0.487 D_fake: 0.482
# saving the latest model (epoch 138, total_steps 157000)
# (epoch: 138, iters: 472, time: 0.156) G_GAN: 0.488 G_GAN_Feat: 2.010 G_VGG: 1.081 D_real: 0.427 D_fake: 0.535
# (epoch: 138, iters: 672, time: 0.156) G_GAN: 0.572 G_GAN_Feat: 2.235 G_VGG: 1.323 D_real: 0.490 D_fake: 0.449
# (epoch: 138, iters: 872, time: 0.156) G_GAN: 0.531 G_GAN_Feat: 2.503 G_VGG: 1.284 D_real: 0.437 D_fake: 0.496
# (epoch: 138, iters: 1072, time: 0.156) G_GAN: 0.745 G_GAN_Feat: 2.278 G_VGG: 1.258 D_real: 0.622 D_fake: 0.324
# End of epoch 138 / 150 	 Time Taken: 179 sec
# (epoch: 139, iters: 128, time: 0.156) G_GAN: 0.597 G_GAN_Feat: 2.346 G_VGG: 0.990 D_real: 0.481 D_fake: 0.432
# saving the latest model (epoch 139, total_steps 158000)
# (epoch: 139, iters: 328, time: 0.156) G_GAN: 0.594 G_GAN_Feat: 2.733 G_VGG: 1.496 D_real: 0.472 D_fake: 0.439
# (epoch: 139, iters: 528, time: 0.156) G_GAN: 0.592 G_GAN_Feat: 2.309 G_VGG: 1.081 D_real: 0.458 D_fake: 0.443
# (epoch: 139, iters: 728, time: 0.156) G_GAN: 0.572 G_GAN_Feat: 2.246 G_VGG: 1.162 D_real: 0.481 D_fake: 0.457
# (epoch: 139, iters: 928, time: 0.156) G_GAN: 0.648 G_GAN_Feat: 2.523 G_VGG: 1.535 D_real: 0.544 D_fake: 0.396
# (epoch: 139, iters: 1128, time: 0.156) G_GAN: 0.577 G_GAN_Feat: 3.141 G_VGG: 1.751 D_real: 0.442 D_fake: 0.454
# saving the latest model (epoch 139, total_steps 159000)
# End of epoch 139 / 150 	 Time Taken: 180 sec
# (epoch: 140, iters: 184, time: 0.156) G_GAN: 0.534 G_GAN_Feat: 2.575 G_VGG: 1.265 D_real: 0.437 D_fake: 0.494
# (epoch: 140, iters: 384, time: 0.156) G_GAN: 0.464 G_GAN_Feat: 2.205 G_VGG: 1.062 D_real: 0.363 D_fake: 0.558
# (epoch: 140, iters: 584, time: 0.156) G_GAN: 0.537 G_GAN_Feat: 2.418 G_VGG: 0.962 D_real: 0.405 D_fake: 0.487
# (epoch: 140, iters: 784, time: 0.156) G_GAN: 0.578 G_GAN_Feat: 2.589 G_VGG: 1.235 D_real: 0.461 D_fake: 0.458
# (epoch: 140, iters: 984, time: 0.156) G_GAN: 0.698 G_GAN_Feat: 2.375 G_VGG: 1.059 D_real: 0.574 D_fake: 0.357
# saving the latest model (epoch 140, total_steps 160000)
# End of epoch 140 / 150 	 Time Taken: 179 sec
# saving the model at the end of epoch 140, iters 160160
# (epoch: 141, iters: 40, time: 0.165) G_GAN: 0.626 G_GAN_Feat: 2.541 G_VGG: 1.159 D_real: 0.503 D_fake: 0.417
# (epoch: 141, iters: 240, time: 0.156) G_GAN: 0.496 G_GAN_Feat: 2.777 G_VGG: 1.274 D_real: 0.386 D_fake: 0.533
# (epoch: 141, iters: 440, time: 0.156) G_GAN: 0.567 G_GAN_Feat: 2.521 G_VGG: 1.245 D_real: 0.488 D_fake: 0.469
# (epoch: 141, iters: 640, time: 0.156) G_GAN: 0.592 G_GAN_Feat: 2.760 G_VGG: 1.252 D_real: 0.471 D_fake: 0.435
# (epoch: 141, iters: 840, time: 0.156) G_GAN: 0.627 G_GAN_Feat: 2.318 G_VGG: 0.899 D_real: 0.518 D_fake: 0.411
# saving the latest model (epoch 141, total_steps 161000)
# (epoch: 141, iters: 1040, time: 0.156) G_GAN: 0.511 G_GAN_Feat: 2.467 G_VGG: 1.143 D_real: 0.448 D_fake: 0.514
# End of epoch 141 / 150 	 Time Taken: 179 sec
# (epoch: 142, iters: 96, time: 0.156) G_GAN: 0.690 G_GAN_Feat: 2.150 G_VGG: 0.981 D_real: 0.582 D_fake: 0.379
# (epoch: 142, iters: 296, time: 0.156) G_GAN: 0.706 G_GAN_Feat: 2.445 G_VGG: 1.151 D_real: 0.579 D_fake: 0.357
# (epoch: 142, iters: 496, time: 0.156) G_GAN: 0.645 G_GAN_Feat: 3.394 G_VGG: 1.493 D_real: 0.458 D_fake: 0.401
# (epoch: 142, iters: 696, time: 0.156) G_GAN: 0.532 G_GAN_Feat: 3.434 G_VGG: 1.753 D_real: 0.362 D_fake: 0.507
# saving the latest model (epoch 142, total_steps 162000)
# (epoch: 142, iters: 896, time: 0.156) G_GAN: 0.594 G_GAN_Feat: 2.710 G_VGG: 1.159 D_real: 0.445 D_fake: 0.436
# (epoch: 142, iters: 1096, time: 0.156) G_GAN: 0.550 G_GAN_Feat: 2.703 G_VGG: 1.423 D_real: 0.414 D_fake: 0.478
# End of epoch 142 / 150 	 Time Taken: 179 sec
# (epoch: 143, iters: 152, time: 0.156) G_GAN: 0.586 G_GAN_Feat: 2.367 G_VGG: 1.072 D_real: 0.498 D_fake: 0.450
# (epoch: 143, iters: 352, time: 0.156) G_GAN: 0.498 G_GAN_Feat: 2.441 G_VGG: 1.171 D_real: 0.425 D_fake: 0.535
# (epoch: 143, iters: 552, time: 0.156) G_GAN: 0.693 G_GAN_Feat: 2.473 G_VGG: 1.029 D_real: 0.560 D_fake: 0.368
# saving the latest model (epoch 143, total_steps 163000)
# (epoch: 143, iters: 752, time: 0.156) G_GAN: 0.558 G_GAN_Feat: 2.290 G_VGG: 1.105 D_real: 0.420 D_fake: 0.470
# (epoch: 143, iters: 952, time: 0.156) G_GAN: 0.533 G_GAN_Feat: 2.667 G_VGG: 1.034 D_real: 0.408 D_fake: 0.498
# End of epoch 143 / 150 	 Time Taken: 179 sec
# (epoch: 144, iters: 8, time: 0.156) G_GAN: 0.564 G_GAN_Feat: 2.473 G_VGG: 1.221 D_real: 0.432 D_fake: 0.476
# (epoch: 144, iters: 208, time: 0.156) G_GAN: 0.636 G_GAN_Feat: 2.309 G_VGG: 0.879 D_real: 0.521 D_fake: 0.413
# (epoch: 144, iters: 408, time: 0.156) G_GAN: 0.599 G_GAN_Feat: 2.512 G_VGG: 1.278 D_real: 0.514 D_fake: 0.433
# saving the latest model (epoch 144, total_steps 164000)
# (epoch: 144, iters: 608, time: 0.156) G_GAN: 0.491 G_GAN_Feat: 2.107 G_VGG: 0.924 D_real: 0.435 D_fake: 0.536
# (epoch: 144, iters: 808, time: 0.156) G_GAN: 0.499 G_GAN_Feat: 2.832 G_VGG: 1.128 D_real: 0.386 D_fake: 0.531
# (epoch: 144, iters: 1008, time: 0.156) G_GAN: 0.498 G_GAN_Feat: 2.686 G_VGG: 1.163 D_real: 0.403 D_fake: 0.536
# End of epoch 144 / 150 	 Time Taken: 179 sec
# (epoch: 145, iters: 64, time: 0.156) G_GAN: 0.653 G_GAN_Feat: 2.209 G_VGG: 0.861 D_real: 0.558 D_fake: 0.394
# (epoch: 145, iters: 264, time: 0.156) G_GAN: 0.658 G_GAN_Feat: 2.632 G_VGG: 1.010 D_real: 0.512 D_fake: 0.402
# saving the latest model (epoch 145, total_steps 165000)
# (epoch: 145, iters: 464, time: 0.156) G_GAN: 0.545 G_GAN_Feat: 2.593 G_VGG: 1.166 D_real: 0.416 D_fake: 0.489
# (epoch: 145, iters: 664, time: 0.156) G_GAN: 0.618 G_GAN_Feat: 2.631 G_VGG: 1.073 D_real: 0.469 D_fake: 0.421
# (epoch: 145, iters: 864, time: 0.156) G_GAN: 0.611 G_GAN_Feat: 2.878 G_VGG: 1.130 D_real: 0.455 D_fake: 0.429
# (epoch: 145, iters: 1064, time: 0.156) G_GAN: 0.752 G_GAN_Feat: 2.437 G_VGG: 1.151 D_real: 0.561 D_fake: 0.323
# End of epoch 145 / 150 	 Time Taken: 179 sec
# (epoch: 146, iters: 120, time: 0.156) G_GAN: 0.622 G_GAN_Feat: 2.980 G_VGG: 1.242 D_real: 0.502 D_fake: 0.421
# saving the latest model (epoch 146, total_steps 166000)
# (epoch: 146, iters: 320, time: 0.156) G_GAN: 0.601 G_GAN_Feat: 1.989 G_VGG: 0.888 D_real: 0.526 D_fake: 0.432
# (epoch: 146, iters: 520, time: 0.156) G_GAN: 0.656 G_GAN_Feat: 2.888 G_VGG: 1.427 D_real: 0.516 D_fake: 0.404
# (epoch: 146, iters: 720, time: 0.156) G_GAN: 0.642 G_GAN_Feat: 2.777 G_VGG: 1.056 D_real: 0.486 D_fake: 0.409
# (epoch: 146, iters: 920, time: 0.156) G_GAN: 0.654 G_GAN_Feat: 2.890 G_VGG: 1.305 D_real: 0.503 D_fake: 0.404
# (epoch: 146, iters: 1120, time: 0.156) G_GAN: 0.623 G_GAN_Feat: 2.673 G_VGG: 1.164 D_real: 0.486 D_fake: 0.420
# saving the latest model (epoch 146, total_steps 167000)
# End of epoch 146 / 150 	 Time Taken: 180 sec
# (epoch: 147, iters: 176, time: 0.156) G_GAN: 0.556 G_GAN_Feat: 2.461 G_VGG: 0.911 D_real: 0.434 D_fake: 0.488
# (epoch: 147, iters: 376, time: 0.156) G_GAN: 0.536 G_GAN_Feat: 2.512 G_VGG: 0.964 D_real: 0.412 D_fake: 0.496
# (epoch: 147, iters: 576, time: 0.156) G_GAN: 0.552 G_GAN_Feat: 2.816 G_VGG: 1.447 D_real: 0.438 D_fake: 0.483
# (epoch: 147, iters: 776, time: 0.156) G_GAN: 0.518 G_GAN_Feat: 2.643 G_VGG: 1.182 D_real: 0.416 D_fake: 0.510
# (epoch: 147, iters: 976, time: 0.156) G_GAN: 0.569 G_GAN_Feat: 2.639 G_VGG: 1.021 D_real: 0.444 D_fake: 0.466
# saving the latest model (epoch 147, total_steps 168000)
# End of epoch 147 / 150 	 Time Taken: 179 sec
# (epoch: 148, iters: 32, time: 0.156) G_GAN: 0.602 G_GAN_Feat: 2.554 G_VGG: 1.217 D_real: 0.459 D_fake: 0.434
# (epoch: 148, iters: 232, time: 0.156) G_GAN: 0.579 G_GAN_Feat: 1.749 G_VGG: 0.714 D_real: 0.507 D_fake: 0.447
# (epoch: 148, iters: 432, time: 0.156) G_GAN: 0.562 G_GAN_Feat: 2.520 G_VGG: 1.000 D_real: 0.438 D_fake: 0.467
# (epoch: 148, iters: 632, time: 0.156) G_GAN: 0.598 G_GAN_Feat: 2.425 G_VGG: 1.096 D_real: 0.529 D_fake: 0.440
# (epoch: 148, iters: 832, time: 0.156) G_GAN: 0.582 G_GAN_Feat: 2.366 G_VGG: 0.874 D_real: 0.451 D_fake: 0.457
# saving the latest model (epoch 148, total_steps 169000)
# (epoch: 148, iters: 1032, time: 0.156) G_GAN: 0.541 G_GAN_Feat: 2.445 G_VGG: 1.026 D_real: 0.416 D_fake: 0.489
# End of epoch 148 / 150 	 Time Taken: 179 sec
# (epoch: 149, iters: 88, time: 0.156) G_GAN: 0.577 G_GAN_Feat: 2.786 G_VGG: 1.049 D_real: 0.453 D_fake: 0.464
# (epoch: 149, iters: 288, time: 0.156) G_GAN: 0.549 G_GAN_Feat: 2.731 G_VGG: 1.297 D_real: 0.438 D_fake: 0.482
# (epoch: 149, iters: 488, time: 0.156) G_GAN: 0.551 G_GAN_Feat: 2.659 G_VGG: 0.955 D_real: 0.409 D_fake: 0.481
# (epoch: 149, iters: 688, time: 0.156) G_GAN: 0.531 G_GAN_Feat: 2.381 G_VGG: 1.046 D_real: 0.448 D_fake: 0.499
# saving the latest model (epoch 149, total_steps 170000)
# (epoch: 149, iters: 888, time: 0.156) G_GAN: 0.565 G_GAN_Feat: 2.707 G_VGG: 1.064 D_real: 0.417 D_fake: 0.475
# (epoch: 149, iters: 1088, time: 0.156) G_GAN: 0.684 G_GAN_Feat: 2.425 G_VGG: 0.897 D_real: 0.521 D_fake: 0.375
# End of epoch 149 / 150 	 Time Taken: 179 sec
# (epoch: 150, iters: 144, time: 0.156) G_GAN: 0.564 G_GAN_Feat: 2.153 G_VGG: 0.996 D_real: 0.501 D_fake: 0.469
# (epoch: 150, iters: 344, time: 0.156) G_GAN: 0.620 G_GAN_Feat: 2.672 G_VGG: 1.198 D_real: 0.476 D_fake: 0.422
# (epoch: 150, iters: 544, time: 0.156) G_GAN: 0.559 G_GAN_Feat: 2.520 G_VGG: 1.029 D_real: 0.424 D_fake: 0.477
# saving the latest model (epoch 150, total_steps 171000)
# (epoch: 150, iters: 744, time: 0.156) G_GAN: 0.622 G_GAN_Feat: 2.572 G_VGG: 1.009 D_real: 0.490 D_fake: 0.425
# (epoch: 150, iters: 944, time: 0.156) G_GAN: 0.537 G_GAN_Feat: 2.587 G_VGG: 0.982 D_real: 0.435 D_fake: 0.490
# (epoch: 150, iters: 1144, time: 0.156) G_GAN: 0.555 G_GAN_Feat: 2.319 G_VGG: 1.123 D_real: 0.455 D_fake: 0.476
# End of epoch 150 / 150 	 Time Taken: 180 sec
# saving the model at the end of epoch 150, iters 171600
